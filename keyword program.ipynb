# %% [markdown]
# <a href="https://colab.research.google.com/github/suyeonlee333333/oss2025/blob/main/keyword%20program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install google-api-python-client youtube_transcript_api
# Out:
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.11/dist-packages (2.164.0)
# Collecting youtube_transcript_api
#   Downloading youtube_transcript_api-1.0.3-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client) (0.22.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client) (2.38.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client) (0.2.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client) (2.24.2)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from youtube_transcript_api) (0.7.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from youtube_transcript_api) (2.32.3)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.69.2)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /usr/local/lib/python3.11/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (5.29.4)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.26.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.11/dist-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client) (3.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->youtube_transcript_api) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->youtube_transcript_api) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->youtube_transcript_api) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->youtube_transcript_api) (2025.1.31)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (0.6.1)
# Downloading youtube_transcript_api-1.0.3-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 36.3 MB/s eta 0:00:00
# Installing collected packages: youtube_transcript_api
# Successfully installed youtube_transcript_api-1.0.3

# %%
# API client library
import googleapiclient.discovery
# API information
api_service_name = "youtube"
api_version = "v3"
API_KEY = "AIzaSyBlzOUagGwDeKx_mxmANSQtLXDZxzq0On8"

# API client
youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey = API_KEY)

# 'request' variable is the only thing you must change
# depending on the resource and method you need to use
# in your query
request = youtube.search().list(
    part="id,snippet",
    type='video',
    q="파이썬",
    videoDuration='medium',
    videoDefinition='high',
    maxResults= 3
)

# Query execution
video_list = request.execute()

# Print the results
video_list
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'ZnRgOkBGZcEfp6f_3H66-b8CjdM',
#  'nextPageToken': 'CAMQAA',
#  'regionCode': 'US',
#  'pageInfo': {'totalResults': 1000000, 'resultsPerPage': 3},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': '-5kUtZv0T4dyVAnBOx9UUFG_WMg',
#    'id': {'kind': 'youtube#video', 'videoId': 'skzOMfk_ftU'},
#    'snippet': {'publishedAt': '2024-01-17T15:37:23Z',
#     'channelId': 'UCUctLJnBsBUTeFQQ3i-Qgvg',
#     'title': '파이썬 배워야 하는 이유, 할 수 있는 것 2가지',
#     'description': '파이썬을 배우고 할 수 있는 것에 대해 알아봅니다. ☀️ 파이썬으로 블로그 자동화 프로그램 만들기(기초) (신규가입, 결제 시 할인 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/skzOMfk_ftU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/skzOMfk_ftU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/skzOMfk_ftU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '파이썬Master',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2024-01-17T15:37:23Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'ZNF-SICuTnHkUuYJ5bvoOi7Wk28',
#    'id': {'kind': 'youtube#video', 'videoId': 'SzNFCim9nDE'},
#    'snippet': {'publishedAt': '2019-09-22T10:14:26Z',
#     'channelId': 'UCfMTqlvqdJgLl283WjdUfOA',
#     'title': '파이썬은 어디에 쓰일까?',
#     'description': '파이썬을 배우면 무슨 일을 할 수 있을까? 파이썬을 배우는 분들 중 많은 분들이 파이썬을 배우면 무슨 일을 할 수 있을까에 대한 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/SzNFCim9nDE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/SzNFCim9nDE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/SzNFCim9nDE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '아케이코딩 - 쉽게 배우는 코딩과 IT',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2019-09-22T10:14:26Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'wT5UzDwgTTTCVtoDtHGKKEPcWxM',
#    'id': {'kind': 'youtube#video', 'videoId': '7ttbyGI5igA'},
#    'snippet': {'publishedAt': '2023-06-18T01:00:04Z',
#     'channelId': 'UCQNE2JmbasNYbjGAcuBiRRg',
#     'title': 'AI 시대 파이썬을 배워야 하는 이유',
#     'description': '2023 점프 투 파이썬 개정 기념 무료 라이브 강의를 진행합니다. 교재: 점프 투 파이썬 (2023년 최신 2차 개정판) ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/7ttbyGI5igA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/7ttbyGI5igA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/7ttbyGI5igA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '조코딩 JoCoding',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-06-18T01:00:04Z'}}]}

# %%
video_list['items'][0]['snippet']['title']
# Out:
# '파이썬 배워야 하는 이유, 할 수 있는 것 2가지'

# %%
from youtube_transcript_api import YouTubeTranscriptApi

# Youtube 자막 추출 함수
def get_transcript(video_id, languages=['ko']):
  transcript = YouTubeTranscriptApi.get_transcript(video_id, languages=['ko'])
  full_transcript = ' '.join([item['text'] for item in transcript])
  return full_transcript

# %%
# Video ID 추출
video_id = video_list['items'][0]['id']['videoId']

# Youtube 영상의 자막 받아오기
full_transcript = get_transcript(video_id)
full_transcript
# Out:
# '안녕하세요 디지털 노가다를 파하는 파이썬 마스터입니다 이번 콘텐츠에서는 파이썬으로 할 수 있는 일에 대해 알아보려고 합니다 지난번 파이썬으로 블로그 자동화 프로그램을 만드는 강의를 오픈하면서 잠깐 언급을 하긴 했었는데 파이썬 공부하시는 분들이 조금 더 목표를 가지고 재미있게 공부하실 수 있도록 내용을 조금 더 가져와 봤습니다 파이썬의 활용도는 오늘 말씀드릴 내용보다 훨씬 더 광범위하다고 보여지지만 일반인 분들의 입장에서 파이썬 공부를 통해 해 볼 수 있는 일은 크게 두 가지가 있습니다 첫 번째로 반복적인 업무를 자동화하는 것입니다 블로그 자동화 뿐만이 아니라 엑셀과 같은 사무 업무도 자동화가 가능합니다 예를 들어서 웹사이트의 데이터를 대량으로 추출하여 엑셀에 저장하고 가공할 수 있습니다 조금 더 실감 나도록 예시를 들어 보겠습니다 네이버 데이터 랩의 쇼핑 인사이트에 들어가시면 인기 검색어 500개가 있습니다 자동 포스팅 등을 활용하기 위해서는 많은 키워드가 필요하기 때문에이 키워드들을 몽땅 가져와서 활용하는 것도 좋을 것입니다 하지만 개수도 많고 또 카테고리별로 많은 키워드들이 있기 때문에이 키워드들을 수작업으로 취합하면 상당히 많은 시간을 들여야 할 수밖에 없습니다 하지만 파이썬을 배우면 이렇게 몇 시간이 들어야 할 작업을 스스로 맞는 프로그램을 만들어 1초 만에 끝낼 수 있게 할 수도 있습니다 남만 사 사용할 것이라면 굳이 UI 디자인을 하실 필요도 없이 코드만 작성해서 사용해도 무방합니다 이렇게 하나의 예시를 들었지만 이처럼 반복적으로 해야 하는 일들을 줄임으로써 눈에 보이진 않지만 엄청난 시간 전략과 함께 경제적인 유익도 얻을 수 있습니다 돈이 들어오고 나가는 것이 보이지 않아서 그렇지 시급이 한 시간에 1만 원에 육박하는 요즘 두 시간만 줄일 수 있다고 하더라도 2만 원이라는 가치를 전략한 수 있는 것입니다 두 번째로 로 프로그램을 판매하거나 외주 활동을 할 수 있습니다 이렇게 나만을 위해 만든 프로그램도 분명 대중성이 있을 수 있습니다 내가 불편함을 느꼈다면 다른 사람도 불편함을 느꼈을 가능성이 높습니다 저 또한 불독사 카페를 그런 계기로 시작하게 되었습니다 그래서 내가 만든 프로그램을 타인에게 공유하고 그 대가를 통해 추가적인 수입을 얻을 수도 있습니다 그리고 크온구 같은 재능 공유 사이트에 내가 만든 프로그램을 올리면 프로그램이 종 종 개발 문의도 들어옵니다 저 같은 경우는 자동 포스팅 자동화 프로그램을 관리하고 카페 및 유튜브 운영으로 인해 바빠서 따로 외주를 하고 있지는 않지만 아래와 같이 마치 퀘스트처럼 과제를 주시는 분들이 있습니다 개발을 하면 건당 최소 수십만 원을 받을 수 있기 때문에 어쩌면 쿠팡 파트너스 애드센스와 같은 노가다성 부어보고 효율적일 수 있습니다 많은 분들이 나도 무언가 만들어서 팔아보고 싶다는 생각을 하실 것입니다 그런데 파이썬을 할 수 있다면 내 아이디어를 구현할 수 있는 무기를 하나 얻게 되는 것이라고 할 수 있습니다 얼마 전 열풍이 많이 불었던 타이탄의 도구라는 책으로 말하자면 하나의 나만의 도구를 얻었다고 할 수 있겠네요 물론 다른 방향으로도 활용할 수 있지만 보통의 일반인들이 파이썬을 배우고자 하는 목적으로이 두 가지 사항만으로 충분하다고 생각합니다 그렇다면 왜 하필 파이썬이 시어도 있고 자바도 있는데 말하실 수 있습니다 그것 것은 일반인들이 가장 쉽게 배울 수 있는 언어이기 때문입니다 예를 들어서 C 언어의 경우 3이라는 숫자를 출력하는 프로그램을 만들려고 하는 경우 다음 화면과 같이 코딩해 주어야 합니다 3 하나의 상수를 출력하 는데도 무척 복잡해 보이죠 출력문을 이야기하는 프린트 fy 경우에도 분명 위에서 넘이라는 변수의 자료형을 선언 했는데도 또 퍼센트 D 아는 출력 타입을 써야 합니다 하지만 파이썬은 다음과 같이 한 문장으로 끝이 납니다 그래서 일반인들도 배워볼 만한 언어라는 것이죠 따라서 파이썬은 내가 먼저 불편하다고 생각하는 것을 자동화하는 방안을 구현해 보고 그것을 타인에게 공유해 본다는 마음 가짐으로 목표를 둔다면 코딩에 대한 기초 지식이 없다고 하더라도 실력을 금방 키울 수 있을 것입니다 코딩이라는 것에 대한 심리적 장벽이 있었다면 그 장벽을 한번 떨쳐 보시기 바랍니다이를 위해 파자마 마스터 카페에서는 실제로 블로그 동화 프로그램을 만들어 보는 예제를 통해 재미있게 파이썬을 공부할 수 있도록 하는 기초 강의가 마련되어 있습니다 관심 있으신 분들은 영상 더보기 링크를 통해서 한번 방문해 보시기 바랍니다 오늘도 영상 시청해 주셔서 감사합니다'

# %%
import requests
import json

# API 정보
WIKI_API_KEY = "qazsxyzewettbovlydshzrtgvepabz"
url = 'http://www.wikifier.org/annotate-article'

params = {
    'text': full_transcript,
    'lang': 'ko',
    'userKey': WIKI_API_KEY,
    'pageRankSqThreshold': 0.8,
    'applyPageRankSqThreshold': 'true',
    'nTopDfValuesToIgnore': 100,
    'nWordsToIgnoreFromList': 100
}

response = requests.post(url, data=params)
wikis = response.json()

wikis
# Out:
# {'annotations': [{'title': '파이썬',
#    'url': 'http://ko.wikipedia.org/wiki/%ed%8c%8c%ec%9d%b4%ec%8d%ac',
#    'lang': 'ko',
#    'pageRank': 0.06922199183567761,
#    'cosine': 0.139601747749656,
#    'secLang': 'en',
#    'secTitle': 'Python (programming language)',
#    'secUrl': 'http://en.wikipedia.org/wiki/Python_(programming_language)',
#    'wikiDataItemId': 'Q28865',
#    'wikiDataClasses': [{'itemId': 'Q899523',
#      'enLabel': 'object-based language'},
#     {'itemId': 'Q1268980', 'enLabel': 'dynamic programming language'},
#     {'itemId': 'Q3839507', 'enLabel': 'functional programming language'},
#     {'itemId': 'Q187432', 'enLabel': 'scripting language'},
#     {'itemId': 'Q12772052', 'enLabel': 'multi-paradigm programming language'},
#     {'itemId': 'Q21562092', 'enLabel': 'imperative programming language'},
#     {'itemId': 'Q1993334', 'enLabel': 'interpreted language'},
#     {'itemId': 'Q211496', 'enLabel': 'high-level programming language'},
#     {'itemId': 'Q9143', 'enLabel': 'programming language'},
#     {'itemId': 'Q1004415', 'enLabel': 'run-time system'},
#     {'itemId': 'Q50843083', 'enLabel': 'off-side rule language'},
#     {'itemId': 'Q28923017', 'enLabel': 'strict programming language'},
#     {'itemId': 'Q629206', 'enLabel': 'computer language'},
#     {'itemId': 'Q7397', 'enLabel': 'software'},
#     {'itemId': 'Q241317', 'enLabel': 'computing platform'},
#     {'itemId': 'Q192161', 'enLabel': 'formal language'},
#     {'itemId': 'Q15621286', 'enLabel': 'intellectual work'},
#     {'itemId': 'Q17537576', 'enLabel': 'creative work'},
#     {'itemId': 'Q47461344', 'enLabel': 'written work'},
#     {'itemId': 'Q12774177', 'enLabel': 'means'},
#     {'itemId': 'Q2424752', 'enLabel': 'product'},
#     {'itemId': 'Q994895', 'enLabel': 'technical system'},
#     {'itemId': 'Q36161', 'enLabel': 'set'},
#     {'itemId': 'Q649732', 'enLabel': 'formal system'},
#     {'itemId': 'Q386724', 'enLabel': 'work'},
#     {'itemId': 'Q131257', 'enLabel': 'intellectual property'},
#     {'itemId': 'Q2143054', 'enLabel': 'material culture'},
#     {'itemId': 'Q488383', 'enLabel': 'object'},
#     {'itemId': 'Q58778', 'enLabel': 'system'},
#     {'itemId': 'Q16686448', 'enLabel': 'artificial object'},
#     {'itemId': 'Q217594', 'enLabel': 'class'},
#     {'itemId': 'Q5469988', 'enLabel': 'formalization'},
#     {'itemId': 'Q864377', 'enLabel': 'multiset'},
#     {'itemId': 'Q3622126', 'enLabel': 'conceptual system'},
#     {'itemId': 'Q1791627', 'enLabel': 'cultural artifact'},
#     {'itemId': 'Q1400881', 'enLabel': 'property'},
#     {'itemId': 'Q427581', 'enLabel': 'intangible asset'},
#     {'itemId': 'Q1146011', 'enLabel': 'exclusive right'},
#     {'itemId': 'Q332624', 'enLabel': 'erga omnes'},
#     {'itemId': 'Q11042', 'enLabel': 'culture'},
#     {'itemId': 'Q23498', 'enLabel': 'archaeology'},
#     {'itemId': 'Q23404', 'enLabel': 'anthropology'},
#     {'itemId': 'Q35120', 'enLabel': 'entity'},
#     {'itemId': 'Q99527517', 'enLabel': 'collective entity'},
#     {'itemId': 'Q7048977', 'enLabel': 'abstract entity'},
#     {'itemId': 'Q246672', 'enLabel': 'mathematical object'},
#     {'itemId': 'Q748349', 'enLabel': 'mathematical structure'},
#     {'itemId': 'Q4393498', 'enLabel': 'representation'},
#     {'itemId': 'Q151885', 'enLabel': 'concept'},
#     {'itemId': 'Q210272', 'enLabel': 'cultural heritage'},
#     {'itemId': 'Q28877', 'enLabel': 'goods'},
#     {'itemId': 'Q46737', 'enLabel': 'asset'},
#     {'itemId': 'Q6042535', 'enLabel': 'intangible property'},
#     {'itemId': 'Q780687', 'enLabel': 'rights'},
#     {'itemId': 'Q2386606', 'enLabel': 'subjective right'},
#     {'itemId': 'Q2515887', 'enLabel': 'pattern of behavior'},
#     {'itemId': 'Q1066186', 'enLabel': 'study of history'},
#     {'itemId': 'Q34749', 'enLabel': 'social science'},
#     {'itemId': 'Q30060700', 'enLabel': 'scientific object'},
#     {'itemId': 'Q4833865', 'enLabel': 'abstract structure'},
#     {'itemId': 'Q930933', 'enLabel': 'relation'},
#     {'itemId': 'Q15916540', 'enLabel': 'semantic unit'},
#     {'itemId': 'Q2145290', 'enLabel': 'mental representation'},
#     {'itemId': 'Q1347367', 'enLabel': 'aptitude'},
#     {'itemId': 'Q2434238', 'enLabel': 'heritage'},
#     {'itemId': 'Q2897903', 'enLabel': 'goods and services'},
#     {'itemId': 'Q1554231', 'enLabel': 'resource'},
#     {'itemId': 'Q2135465', 'enLabel': 'legal concept'},
#     {'itemId': 'Q321839', 'enLabel': 'agreement'},
#     {'itemId': 'Q7748', 'enLabel': 'law'},
#     {'itemId': 'Q2083958', 'enLabel': 'pattern'},
#     {'itemId': 'Q3769299', 'enLabel': 'human behavior'},
#     {'itemId': 'Q80083', 'enLabel': 'humanities'},
#     {'itemId': 'Q33122512', 'enLabel': 'social sciences and humanities'},
#     {'itemId': 'Q937228', 'enLabel': 'property'},
#     {'itemId': 'Q1786828', 'enLabel': 'constituent'},
#     {'itemId': 'Q1272626', 'enLabel': 'representation'},
#     {'itemId': 'Q1207505', 'enLabel': 'quality'},
#     {'itemId': 'Q58415929', 'enLabel': 'spatio-temporal entity'},
#     {'itemId': 'Q53617489', 'enLabel': 'independent continuant'},
#     {'itemId': 'Q31464082', 'enLabel': 'source'},
#     {'itemId': 'Q1969448', 'enLabel': 'term'},
#     {'itemId': 'Q2006324', 'enLabel': 'agreement'},
#     {'itemId': 'Q1151067', 'enLabel': 'rule'},
#     {'itemId': 'Q4184950', 'enLabel': 'regularity'},
#     {'itemId': 'Q9332', 'enLabel': 'behavior'},
#     {'itemId': 'Q11862829', 'enLabel': 'academic discipline'},
#     {'itemId': 'Q336', 'enLabel': 'science'},
#     {'itemId': 'Q5371079', 'enLabel': 'emic unit'},
#     {'itemId': 'Q3695082', 'enLabel': 'sign'},
#     {'itemId': 'Q103940464', 'enLabel': 'continuant'},
#     {'itemId': 'Q115372263', 'enLabel': 'word or phrase'},
#     {'itemId': 'Q151411', 'enLabel': 'designation'},
#     {'itemId': 'Q202722', 'enLabel': 'consensus'},
#     {'itemId': 'Q628523', 'enLabel': 'message'},
#     {'itemId': 'Q1047113', 'enLabel': 'specialty'},
#     {'itemId': 'Q105948247', 'enLabel': 'knowledge system'},
#     {'itemId': 'Q11953984', 'enLabel': 'linguistic unit'},
#     {'itemId': 'Q115786086', 'enLabel': 'linguistic form'},
#     {'itemId': 'Q3505845', 'enLabel': 'state'},
#     {'itemId': 'Q1190554', 'enLabel': 'occurrence'},
#     {'itemId': 'Q11028', 'enLabel': 'information'},
#     {'itemId': 'Q110403031', 'enLabel': 'knowledge type'},
#     {'itemId': 'Q9081', 'enLabel': 'knowledge'},
#     {'itemId': 'Q26256810', 'enLabel': 'matter'},
#     {'itemId': 'Q2198779', 'enLabel': 'unit'},
#     {'itemId': 'Q115820013', 'enLabel': 'unit of speech'},
#     {'itemId': 'Q483247', 'enLabel': 'phenomenon'},
#     {'itemId': 'Q67518978', 'enLabel': 'occurrent'},
#     {'itemId': 'Q21146257', 'enLabel': 'type'},
#     {'itemId': 'Q104127086', 'enLabel': 'memory'},
#     {'itemId': 'Q12488383', 'enLabel': 'content'},
#     {'itemId': 'Q47574', 'enLabel': 'unit of measurement'},
#     {'itemId': 'Q30241068', 'enLabel': 'observable entity'},
#     {'itemId': 'Q16889133', 'enLabel': 'class'},
#     {'itemId': 'Q39875001', 'enLabel': 'measure'},
#     {'itemId': 'Q181175', 'enLabel': 'scalar quantity'},
#     {'itemId': 'Q71550118', 'enLabel': 'individual quantity'},
#     {'itemId': 'Q5127848', 'enLabel': 'class'},
#     {'itemId': 'Q107715', 'enLabel': 'physical quantity'},
#     {'itemId': 'Q1289248', 'enLabel': 'scalar'},
#     {'itemId': 'Q309314', 'enLabel': 'quantity'},
#     {'itemId': 'Q122375923', 'enLabel': 'abstract class'},
#     {'itemId': 'Q4373292', 'enLabel': 'physical property'},
#     {'itemId': 'Q2204117', 'enLabel': 'symmetric tensor'},
#     {'itemId': 'Q1325769', 'enLabel': 'antisymmetric tensor'},
#     {'itemId': 'Q2091629', 'enLabel': 'magnitude'},
#     {'itemId': 'Q2912517', 'enLabel': 'value'},
#     {'itemId': 'Q38885242', 'enLabel': 'physico-chemical property'},
#     {'itemId': 'Q188524', 'enLabel': 'tensor'},
#     {'itemId': 'Q1952404', 'enLabel': 'multilinear map'},
#     {'itemId': 'Q370502', 'enLabel': 'mapping'},
#     {'itemId': 'Q11348', 'enLabel': 'function'},
#     {'itemId': 'Q29182544', 'enLabel': 'assignment'},
#     {'itemId': 'Q130901', 'enLabel': 'binary relation'},
#     {'itemId': 'Q1756942', 'enLabel': 'partial function'},
#     {'itemId': 'Q629085', 'enLabel': 'multivalued function'},
#     {'itemId': 'Q846537', 'enLabel': 'generalized function'},
#     {'itemId': 'Q4026292', 'enLabel': 'action'},
#     {'itemId': 'Q203066', 'enLabel': 'relation'},
#     {'itemId': 'Q54940067', 'enLabel': 'serial relation'},
#     {'itemId': 'Q107223533', 'enLabel': 'relation (mathematics)'}],
#    'dbPediaTypes': ['Work', 'Software', 'ProgrammingLanguage'],
#    'dbPediaIri': 'http://dbpedia.org/resource/Python_(programming_language)',
#    'supportLen': 13,
#    'support': [{'wFrom': 4,
#      'wTo': 4,
#      'chFrom': 19,
#      'chTo': 21,
#      'pMentionGivenSurface': 0.7835616438356164,
#      'pageRank': 0.005592773594413843,
#      'prbConfidence': 1,
#      'entropy': 0},
#     {'wFrom': 8,
#      'wTo': 8,
#      'chFrom': 40,
#      'chTo': 44,
#      'pMentionGivenSurface': 0.8055555555555556,
#      'pageRank': 0.005749758012516563,
#      'prbConfidence': 1,
#      'entropy': 0},
#     {'wFrom': 17,
#      'wTo': 17,
#      'chFrom': 73,
#      'chTo': 77,
#      'pMentionGivenSurface': 0.8055555555555556,
#      'pageRank': 0.005749758012516563,
#      'prbConfidence': 1,
#      'entropy': 0},
#     {'wFrom': 28,
#      'wTo': 28,
#      'chFrom': 122,
#      'chTo': 124,
#      'pMentionGivenSurface': 0.7835616438356164,
#      'pageRank': 0.005592773594413843,
#      'prbConfidence': 1,
#      'entropy': 0},
#     {'wFrom': 44,
#      'wTo': 44,
#      'chFrom': 183,
#      'chTo': 186,
#      'pMentionGivenSurface': 0.48,
#      'pageRank': 0.00342606270538918,
#      'prbConfidence': 1,
#      'entropy': 0},
#     {'wFrom': 56,
#      'wTo': 56,
#      'chFrom': 237,
#      'chTo': 239,
#      'pMentionGivenSurface': 0.7835616438356164,
#      'pageRank': 0.005592773594413843,
#      'prbConfidence': 1,
#      'entropy': 0},
#     {'wFrom': 148,
#      'wTo': 148,
#      'chFrom': 610,
#      'chTo': 613,
#      'pMentionGivenSurface': 0.65,
#      'pageRank': 0.004639459913547847,
#      'prbConfidence': 1,
#      'entropy': 0},
#     {'wFrom': 356,
#      'wTo': 356,
#      'chFrom': 1401,
#      'chTo': 1404,
#      'pMentionGivenSurface': 0.65,
#      'pageRank': 0.004639459913547847,
#      'prbConfidence': 1,
#      'entropy': 0},
#     {'wFrom': 397,
#      'wTo': 397,
#      'chFrom': 1551,
#      'chTo': 1554,
#      'pMentionGivenSurface': 0.65,
#      'pageRank': 0.004639459913547847,
#      'prbConfidence': 1,
#      'entropy': 0},
#     {'wFrom': 409,
#      'wTo': 409,
#      'chFrom': 1603,
#      'chTo': 1606,
#      'pMentionGivenSurface': 0.4,
#      'pageRank': 0.002855052254490983,
#      'prbConfidence': 1,
#      'entropy': 0},
#     {'wFrom': 474,
#      'wTo': 474,
#      'chFrom': 1850,
#      'chTo': 1853,
#      'pMentionGivenSurface': 0.6153846153846154,
#      'pageRank': 0.004392388083832282,
#      'prbConfidence': 1,
#      'entropy': 0},
#     {'wFrom': 488,
#      'wTo': 488,
#      'chFrom': 1906,
#      'chTo': 1909,
#      'pMentionGivenSurface': 0.6153846153846154,
#      'pageRank': 0.004392388083832282,
#      'prbConfidence': 1,
#      'entropy': 0},
#     {'wFrom': 543,
#      'wTo': 543,
#      'chFrom': 2125,
#      'chTo': 2128,
#      'pMentionGivenSurface': 0.65,
#      'pageRank': 0.004639459913547847,
#      'prbConfidence': 1,
#      'entropy': 0}]},
#   {'title': '구글',
#    'url': 'http://ko.wikipedia.org/wiki/%ea%b5%ac%ea%b8%80',
#    'lang': 'ko',
#    'pageRank': 0.01254594287561885,
#    'cosine': 0.04827900548829601,
#    'secLang': 'en',
#    'secTitle': 'Google',
#    'secUrl': 'http://en.wikipedia.org/wiki/Google',
#    'wikiDataItemId': 'Q95',
#    'wikiDataClasses': [{'itemId': 'Q4830453', 'enLabel': 'business'},
#     {'itemId': 'Q18388277', 'enLabel': 'technology company'},
#     {'itemId': 'Q5988403', 'enLabel': 'identity provider'},
#     {'itemId': 'Q891723', 'enLabel': 'public company'},
#     {'itemId': 'Q19967801', 'enLabel': 'online service'},
#     {'itemId': 'Q43229', 'enLabel': 'organization'},
#     {'itemId': 'Q12569864', 'enLabel': 'economic entity'},
#     {'itemId': 'Q155076', 'enLabel': 'juridical person'},
#     {'itemId': 'Q167037', 'enLabel': 'corporation'},
#     {'itemId': 'Q6881511', 'enLabel': 'enterprise'},
#     {'itemId': 'Q784561', 'enLabel': 'authentication server'},
#     {'itemId': 'Q134161', 'enLabel': 'joint-stock company'},
#     {'itemId': 'Q1668024', 'enLabel': 'service on Internet'},
#     {'itemId': 'Q11492760', 'enLabel': 'information services'},
#     {'itemId': 'Q106559804', 'enLabel': 'person or organization'},
#     {'itemId': 'Q106668099', 'enLabel': 'corporate body'},
#     {'itemId': 'Q1639378', 'enLabel': 'social system'},
#     {'itemId': 'Q854457', 'enLabel': 'complex system'},
#     {'itemId': 'Q3778211', 'enLabel': 'legal person'},
#     {'itemId': 'Q783794', 'enLabel': 'company'},
#     {'itemId': 'Q1371279', 'enLabel': 'server software'},
#     {'itemId': 'Q33685', 'enLabel': 'limited company'},
#     {'itemId': 'Q1273271', 'enLabel': 'e-service'},
#     {'itemId': 'Q1640628', 'enLabel': 'network service'},
#     {'itemId': 'Q340169', 'enLabel': 'media'},
#     {'itemId': 'Q7406919', 'enLabel': 'service'},
#     {'itemId': 'Q24229398', 'enLabel': 'agent'},
#     {'itemId': 'Q488383', 'enLabel': 'object'},
#     {'itemId': 'Q131085629', 'enLabel': 'collective agent'},
#     {'itemId': 'Q58778', 'enLabel': 'system'},
#     {'itemId': 'Q21980538', 'enLabel': 'commercial organization'},
#     {'itemId': 'Q16334295', 'enLabel': 'group of humans'},
#     {'itemId': 'Q7397', 'enLabel': 'software'},
#     {'itemId': 'Q44127', 'enLabel': 'server'},
#     {'itemId': 'Q567521', 'enLabel': 'commercial company'},
#     {'itemId': 'Q146923', 'enLabel': 'middleware of distributed system'},
#     {'itemId': 'Q12774177', 'enLabel': 'means'},
#     {'itemId': 'Q104450446', 'enLabel': 'data carrier'},
#     {'itemId': 'Q2897903', 'enLabel': 'goods and services'},
#     {'itemId': 'Q2424752', 'enLabel': 'product'},
#     {'itemId': 'Q8187769', 'enLabel': 'economic activity'},
#     {'itemId': 'Q53617489', 'enLabel': 'independent continuant'},
#     {'itemId': 'Q830077', 'enLabel': 'subject'},
#     {'itemId': 'Q35120', 'enLabel': 'entity'},
#     {'itemId': 'Q99527517', 'enLabel': 'collective entity'},
#     {'itemId': 'Q7048977', 'enLabel': 'abstract entity'},
#     {'itemId': 'Q16334298', 'enLabel': 'group of living things'},
#     {'itemId': 'Q17537576', 'enLabel': 'creative work'},
#     {'itemId': 'Q47461344', 'enLabel': 'written work'},
#     {'itemId': 'Q994895', 'enLabel': 'technical system'},
#     {'itemId': 'Q4925872', 'enLabel': 'data processing system'},
#     {'itemId': 'Q5621421', 'enLabel': 'private company'},
#     {'itemId': 'Q146768', 'enLabel': 'middleware'},
#     {'itemId': 'Q17538423', 'enLabel': 'manifestation'},
#     {'itemId': 'Q58415929', 'enLabel': 'spatio-temporal entity'},
#     {'itemId': 'Q451967', 'enLabel': 'intentional human activity'},
#     {'itemId': 'Q125506646', 'enLabel': 'transfer'},
#     {'itemId': 'Q103940464', 'enLabel': 'continuant'},
#     {'itemId': 'Q61961344', 'enLabel': 'group of physical objects'},
#     {'itemId': 'Q15621286', 'enLabel': 'intellectual work'},
#     {'itemId': 'Q2143054', 'enLabel': 'material culture'},
#     {'itemId': 'Q16686448', 'enLabel': 'artificial object'},
#     {'itemId': 'Q121182', 'enLabel': 'information system'},
#     {'itemId': 'Q676202', 'enLabel': 'system software'},
#     {'itemId': 'Q61788060', 'enLabel': 'human activity'},
#     {'itemId': 'Q1150070', 'enLabel': 'change'},
#     {'itemId': 'Q52948', 'enLabel': 'interaction'},
#     {'itemId': 'Q98119401', 'enLabel': 'group or class of physical objects'},
#     {'itemId': 'Q386724', 'enLabel': 'work'},
#     {'itemId': 'Q131257', 'enLabel': 'intellectual property'},
#     {'itemId': 'Q11042', 'enLabel': 'culture'},
#     {'itemId': 'Q23498', 'enLabel': 'archaeology'},
#     {'itemId': 'Q23404', 'enLabel': 'anthropology'},
#     {'itemId': 'Q1914636', 'enLabel': 'activity'},
#     {'itemId': 'Q3769299', 'enLabel': 'human behavior'},
#     {'itemId': 'Q67518978', 'enLabel': 'occurrent'},
#     {'itemId': 'Q111931734', 'enLabel': 'effect'},
#     {'itemId': 'Q930933', 'enLabel': 'relation'},
#     {'itemId': 'Q1791627', 'enLabel': 'cultural artifact'},
#     {'itemId': 'Q1400881', 'enLabel': 'property'},
#     {'itemId': 'Q427581', 'enLabel': 'intangible asset'},
#     {'itemId': 'Q1146011', 'enLabel': 'exclusive right'},
#     {'itemId': 'Q332624', 'enLabel': 'erga omnes'},
#     {'itemId': 'Q2515887', 'enLabel': 'pattern of behavior'},
#     {'itemId': 'Q1066186', 'enLabel': 'study of history'},
#     {'itemId': 'Q34749', 'enLabel': 'social science'},
#     {'itemId': 'Q3249551', 'enLabel': 'process'},
#     {'itemId': 'Q9332', 'enLabel': 'behavior'},
#     {'itemId': 'Q4026292', 'enLabel': 'action'},
#     {'itemId': 'Q937228', 'enLabel': 'property'},
#     {'itemId': 'Q210272', 'enLabel': 'cultural heritage'},
#     {'itemId': 'Q28877', 'enLabel': 'goods'},
#     {'itemId': 'Q46737', 'enLabel': 'asset'},
#     {'itemId': 'Q6042535', 'enLabel': 'intangible property'},
#     {'itemId': 'Q780687', 'enLabel': 'rights'},
#     {'itemId': 'Q2386606', 'enLabel': 'subjective right'},
#     {'itemId': 'Q2083958', 'enLabel': 'pattern'},
#     {'itemId': 'Q80083', 'enLabel': 'humanities'},
#     {'itemId': 'Q33122512', 'enLabel': 'social sciences and humanities'},
#     {'itemId': 'Q20937557', 'enLabel': 'sequence'},
#     {'itemId': 'Q1190554', 'enLabel': 'occurrence'},
#     {'itemId': 'Q2434238', 'enLabel': 'heritage'},
#     {'itemId': 'Q1554231', 'enLabel': 'resource'},
#     {'itemId': 'Q2135465', 'enLabel': 'legal concept'},
#     {'itemId': 'Q321839', 'enLabel': 'agreement'},
#     {'itemId': 'Q7748', 'enLabel': 'law'},
#     {'itemId': 'Q4184950', 'enLabel': 'regularity'},
#     {'itemId': 'Q11862829', 'enLabel': 'academic discipline'},
#     {'itemId': 'Q336', 'enLabel': 'science'},
#     {'itemId': 'Q16889133', 'enLabel': 'class'},
#     {'itemId': 'Q31464082', 'enLabel': 'source'},
#     {'itemId': 'Q151885', 'enLabel': 'concept'},
#     {'itemId': 'Q1969448', 'enLabel': 'term'},
#     {'itemId': 'Q2006324', 'enLabel': 'agreement'},
#     {'itemId': 'Q1151067', 'enLabel': 'rule'},
#     {'itemId': 'Q1047113', 'enLabel': 'specialty'},
#     {'itemId': 'Q105948247', 'enLabel': 'knowledge system'},
#     {'itemId': 'Q5127848', 'enLabel': 'class'},
#     {'itemId': 'Q15916540', 'enLabel': 'semantic unit'},
#     {'itemId': 'Q2145290', 'enLabel': 'mental representation'},
#     {'itemId': 'Q1347367', 'enLabel': 'aptitude'},
#     {'itemId': 'Q115372263', 'enLabel': 'word or phrase'},
#     {'itemId': 'Q151411', 'enLabel': 'designation'},
#     {'itemId': 'Q202722', 'enLabel': 'consensus'},
#     {'itemId': 'Q628523', 'enLabel': 'message'},
#     {'itemId': 'Q110403031', 'enLabel': 'knowledge type'},
#     {'itemId': 'Q9081', 'enLabel': 'knowledge'},
#     {'itemId': 'Q26256810', 'enLabel': 'matter'},
#     {'itemId': 'Q3622126', 'enLabel': 'conceptual system'},
#     {'itemId': 'Q1786828', 'enLabel': 'constituent'},
#     {'itemId': 'Q1272626', 'enLabel': 'representation'},
#     {'itemId': 'Q1207505', 'enLabel': 'quality'},
#     {'itemId': 'Q115786086', 'enLabel': 'linguistic form'},
#     {'itemId': 'Q3505845', 'enLabel': 'state'},
#     {'itemId': 'Q11028', 'enLabel': 'information'},
#     {'itemId': 'Q21146257', 'enLabel': 'type'},
#     {'itemId': 'Q104127086', 'enLabel': 'memory'},
#     {'itemId': 'Q12488383', 'enLabel': 'content'},
#     {'itemId': 'Q5371079', 'enLabel': 'emic unit'},
#     {'itemId': 'Q3695082', 'enLabel': 'sign'},
#     {'itemId': 'Q11953984', 'enLabel': 'linguistic unit'},
#     {'itemId': 'Q115820013', 'enLabel': 'unit of speech'},
#     {'itemId': 'Q483247', 'enLabel': 'phenomenon'},
#     {'itemId': 'Q2198779', 'enLabel': 'unit'},
#     {'itemId': 'Q30241068', 'enLabel': 'observable entity'},
#     {'itemId': 'Q47574', 'enLabel': 'unit of measurement'},
#     {'itemId': 'Q39875001', 'enLabel': 'measure'},
#     {'itemId': 'Q181175', 'enLabel': 'scalar quantity'},
#     {'itemId': 'Q71550118', 'enLabel': 'individual quantity'},
#     {'itemId': 'Q107715', 'enLabel': 'physical quantity'},
#     {'itemId': 'Q1289248', 'enLabel': 'scalar'},
#     {'itemId': 'Q309314', 'enLabel': 'quantity'},
#     {'itemId': 'Q122375923', 'enLabel': 'abstract class'},
#     {'itemId': 'Q4373292', 'enLabel': 'physical property'},
#     {'itemId': 'Q2204117', 'enLabel': 'symmetric tensor'},
#     {'itemId': 'Q1325769', 'enLabel': 'antisymmetric tensor'},
#     {'itemId': 'Q2091629', 'enLabel': 'magnitude'},
#     {'itemId': 'Q2912517', 'enLabel': 'value'},
#     {'itemId': 'Q38885242', 'enLabel': 'physico-chemical property'},
#     {'itemId': 'Q188524', 'enLabel': 'tensor'},
#     {'itemId': 'Q246672', 'enLabel': 'mathematical object'},
#     {'itemId': 'Q1952404', 'enLabel': 'multilinear map'},
#     {'itemId': 'Q30060700', 'enLabel': 'scientific object'},
#     {'itemId': 'Q370502', 'enLabel': 'mapping'},
#     {'itemId': 'Q11348', 'enLabel': 'function'},
#     {'itemId': 'Q29182544', 'enLabel': 'assignment'},
#     {'itemId': 'Q130901', 'enLabel': 'binary relation'},
#     {'itemId': 'Q1756942', 'enLabel': 'partial function'},
#     {'itemId': 'Q629085', 'enLabel': 'multivalued function'},
#     {'itemId': 'Q846537', 'enLabel': 'generalized function'},
#     {'itemId': 'Q203066', 'enLabel': 'relation'},
#     {'itemId': 'Q54940067', 'enLabel': 'serial relation'},
#     {'itemId': 'Q36161', 'enLabel': 'set'},
#     {'itemId': 'Q107223533', 'enLabel': 'relation (mathematics)'},
#     {'itemId': 'Q217594', 'enLabel': 'class'},
#     {'itemId': 'Q5469988', 'enLabel': 'formalization'},
#     {'itemId': 'Q864377', 'enLabel': 'multiset'},
#     {'itemId': 'Q748349', 'enLabel': 'mathematical structure'},
#     {'itemId': 'Q4393498', 'enLabel': 'representation'},
#     {'itemId': 'Q4833865', 'enLabel': 'abstract structure'}],
#    'dbPediaTypes': ['Agent', 'Place', 'Organisation', 'Company'],
#    'dbPediaIri': 'http://dbpedia.org/resource/Google',
#    'supportLen': 13,
#    'support': [{'wFrom': 67,
#      'wTo': 67,
#      'chFrom': 269,
#      'chTo': 272,
#      'pMentionGivenSurface': 0.0004982561036372695,
#      'pageRank': 3.556368030008698e-06,
#      'prbConfidence': 1,
#      'entropy': 0},
#     {'wFrom': 94,
#      'wTo': 94,
#      'chFrom': 384,
#      'chTo': 387,
#      'pMentionGivenSurface': 0.0004982561036372695,
#      'pageRank': 3.556368030008698e-06,
#      'prbConfidence': 1,
#      'entropy': 0},
#     {'wFrom': 111,
#      'wTo': 111,
#      'chFrom': 453,
#      'chTo': 456,
#      'pMentionGivenSurface': 0.0004982561036372695,
#      'pageRank': 3.556368030008698e-06,
#      'prbConfidence': 1,
#      'entropy': 0},
#     {'wFrom': 167,
#      'wTo': 167,
#      'chFrom': 675,
#      'chTo': 678,
#      'pMentionGivenSurface': 0.0004982561036372695,
#      'pageRank': 3.556368030008698e-06,
#      'prbConfidence': 1,
#      'entropy': 0},
#     {'wFrom': 203,
#      'wTo': 203,
#      'chFrom': 817,
#      'chTo': 820,
#      'pMentionGivenSurface': 0.0004982561036372695,
#      'pageRank': 3.556368030008698e-06,
#      'prbConfidence': 1,
#      'entropy': 0},
#     {'wFrom': 240,
#      'wTo': 240,
#      'chFrom': 950,
#      'chTo': 953,
#      'pMentionGivenSurface': 0.0004982561036372695,
#      'pageRank': 3.556368030008698e-06,
#      'prbConfidence': 1,
#      'entropy': 0},
#     {'wFrom': 250,
#      'wTo': 250,
#      'chFrom': 988,
#      'chTo': 991,
#      'pMentionGivenSurface': 0.0004982561036372695,
#      'pageRank': 3.556368030008698e-06,
#      'prbConfidence': 1,
#      'entropy': 0},
#     {'wFrom': 281,
#      'wTo': 281,
#      'chFrom': 1113,
#      'chTo': 1116,
#      'pMentionGivenSurface': 0.0004982561036372695,
#      'pageRank': 3.556368030008698e-06,
#      'prbConfidence': 1,
#      'entropy': 0},
#     {'wFrom': 324,
#      'wTo': 324,
#      'chFrom': 1277,
#      'chTo': 1280,
#      'pMentionGivenSurface': 0.0004982561036372695,
#      'pageRank': 3.556368030008698e-06,
#      'prbConfidence': 1,
#      'entropy': 0},
#     {'wFrom': 344,
#      'wTo': 344,
#      'chFrom': 1352,
#      'chTo': 1355,
#      'pMentionGivenSurface': 0.0004982561036372695,
#      'pageRank': 3.556368030008698e-06,
#      'prbConfidence': 1,
#      'entropy': 0},
#     {'wFrom': 372,
#      'wTo': 372,
#      'chFrom': 1453,
#      'chTo': 1456,
#      'pMentionGivenSurface': 0.0004982561036372695,
#      'pageRank': 3.556368030008698e-06,
#      'prbConfidence': 1,
#      'entropy': 0},
#     {'wFrom': 416,
#      'wTo': 416,
#      'chFrom': 1629,
#      'chTo': 1632,
#      'pMentionGivenSurface': 0.0004982561036372695,
#      'pageRank': 3.556368030008698e-06,
#      'prbConfidence': 1,
#      'entropy': 0},
#     {'wFrom': 551,
#      'wTo': 551,
#      'chFrom': 2155,
#      'chTo': 2158,
#      'pMentionGivenSurface': 0.0004982561036372695,
#      'pageRank': 3.556368030008698e-06,
#      'prbConfidence': 1,
#      'entropy': 0}]},
#   {'title': '웹사이트',
#    'url': 'http://ko.wikipedia.org/wiki/%ec%9b%b9%ec%82%ac%ec%9d%b4%ed%8a%b8',
#    'lang': 'ko',
#    'pageRank': 0.01095083211329022,
#    'cosine': 0.02384782122007272,
#    'secLang': 'en',
#    'secTitle': 'Website',
#    'secUrl': 'http://en.wikipedia.org/wiki/Website',
#    'wikiDataItemId': 'Q35127',
#    'wikiDataClasses': [],
#    'dbPediaTypes': [],
#    'dbPediaIri': 'http://dbpedia.org/resource/Website',
#    'supportLen': 1,
#    'support': [{'wFrom': 86,
#      'wTo': 86,
#      'chFrom': 348,
#      'chTo': 352,
#      'pMentionGivenSurface': 0.08,
#      'pageRank': 0.0005710104508981965,
#      'prbConfidence': 1,
#      'entropy': 0}]},
#   {'title': '그래픽 사용자 인터페이스',
#    'url': 'http://ko.wikipedia.org/wiki/%ea%b7%b8%eb%9e%98%ed%94%bd_%ec%82%ac%ec%9a%a9%ec%9e%90_%ec%9d%b8%ed%84%b0%ed%8e%98%ec%9d%b4%ec%8a%a4',
#    'lang': 'ko',
#    'pageRank': 0.0122550802581968,
#    'cosine': 0.01457221040493487,
#    'secLang': 'en',
#    'secTitle': 'Graphical user interface',
#    'secUrl': 'http://en.wikipedia.org/wiki/Graphical_user_interface',
#    'wikiDataItemId': 'Q782543',
#    'wikiDataClasses': [{'itemId': 'Q17155032', 'enLabel': 'software category'},
#     {'itemId': 'Q16889133', 'enLabel': 'class'},
#     {'itemId': 'Q63981612', 'enLabel': 'product category'},
#     {'itemId': 'Q483394', 'enLabel': 'genre'},
#     {'itemId': 'Q5127848', 'enLabel': 'class'},
#     {'itemId': 'Q7048977', 'enLabel': 'abstract entity'},
#     {'itemId': 'Q16887380', 'enLabel': 'group'},
#     {'itemId': 'Q96251598', 'enLabel': 'type of object'},
#     {'itemId': 'Q99527517', 'enLabel': 'collective entity'},
#     {'itemId': 'Q35120', 'enLabel': 'entity'},
#     {'itemId': 'Q21146257', 'enLabel': 'type'},
#     {'itemId': 'Q104086571', 'enLabel': 'first-order class'},
#     {'itemId': 'Q23959932', 'enLabel': 'fixed-order class'}],
#    'dbPediaTypes': ['MusicGenre', 'Genre', 'TopicalConcept'],
#    'dbPediaIri': 'http://dbpedia.org/resource/Graphical_user_interface',
#    'supportLen': 1,
#    'support': [{'wFrom': 173,
#      'wTo': 173,
#      'chFrom': 697,
#      'chTo': 698,
#      'pMentionGivenSurface': 0.065625,
#      'pageRank': 0.0004684070105024269,
#      'prbConfidence': 0.5433566630900656,
#      'entropy': 0.3372900666170139}]},
#   {'title': '소프트웨어 개발',
#    'url': 'http://ko.wikipedia.org/wiki/%ec%86%8c%ed%94%84%ed%8a%b8%ec%9b%a8%ec%96%b4_%ea%b0%9c%eb%b0%9c',
#    'lang': 'ko',
#    'pageRank': 0.01112653315779549,
#    'cosine': 0.01236439768446759,
#    'secLang': 'en',
#    'secTitle': 'Software development',
#    'secUrl': 'http://en.wikipedia.org/wiki/Software_development',
#    'wikiDataItemId': 'Q638608',
#    'wikiDataClasses': [{'itemId': 'Q119143679',
#      'enLabel': 'system lifecycle phase'},
#     {'itemId': 'Q11862829', 'enLabel': 'academic discipline'},
#     {'itemId': 'Q1047113', 'enLabel': 'specialty'},
#     {'itemId': 'Q2267705', 'enLabel': 'field of study'},
#     {'itemId': 'Q1188986', 'enLabel': 'phase'},
#     {'itemId': 'Q105948247', 'enLabel': 'knowledge system'},
#     {'itemId': 'Q110403031', 'enLabel': 'knowledge type'},
#     {'itemId': 'Q9081', 'enLabel': 'knowledge'},
#     {'itemId': 'Q26256810', 'enLabel': 'matter'},
#     {'itemId': 'Q186081', 'enLabel': 'time interval'},
#     {'itemId': 'Q3622126', 'enLabel': 'conceptual system'},
#     {'itemId': 'Q21146257', 'enLabel': 'type'},
#     {'itemId': 'Q104127086', 'enLabel': 'memory'},
#     {'itemId': 'Q11028', 'enLabel': 'information'},
#     {'itemId': 'Q12488383', 'enLabel': 'content'},
#     {'itemId': 'Q26907166', 'enLabel': 'temporal entity'},
#     {'itemId': 'Q58778', 'enLabel': 'system'},
#     {'itemId': 'Q16686448', 'enLabel': 'artificial object'},
#     {'itemId': 'Q7048977', 'enLabel': 'abstract entity'},
#     {'itemId': 'Q151885', 'enLabel': 'concept'},
#     {'itemId': 'Q16889133', 'enLabel': 'class'},
#     {'itemId': 'Q58415929', 'enLabel': 'spatio-temporal entity'},
#     {'itemId': 'Q99527517', 'enLabel': 'collective entity'},
#     {'itemId': 'Q488383', 'enLabel': 'object'},
#     {'itemId': 'Q35120', 'enLabel': 'entity'},
#     {'itemId': 'Q15916540', 'enLabel': 'semantic unit'},
#     {'itemId': 'Q2145290', 'enLabel': 'mental representation'},
#     {'itemId': 'Q1347367', 'enLabel': 'aptitude'},
#     {'itemId': 'Q5127848', 'enLabel': 'class'},
#     {'itemId': 'Q1786828', 'enLabel': 'constituent'},
#     {'itemId': 'Q1272626', 'enLabel': 'representation'},
#     {'itemId': 'Q1207505', 'enLabel': 'quality'},
#     {'itemId': 'Q5371079', 'enLabel': 'emic unit'},
#     {'itemId': 'Q3695082', 'enLabel': 'sign'},
#     {'itemId': 'Q937228', 'enLabel': 'property'},
#     {'itemId': 'Q11953984', 'enLabel': 'linguistic unit'},
#     {'itemId': 'Q2198779', 'enLabel': 'unit'},
#     {'itemId': 'Q47574', 'enLabel': 'unit of measurement'},
#     {'itemId': 'Q39875001', 'enLabel': 'measure'},
#     {'itemId': 'Q181175', 'enLabel': 'scalar quantity'},
#     {'itemId': 'Q71550118', 'enLabel': 'individual quantity'},
#     {'itemId': 'Q107715', 'enLabel': 'physical quantity'},
#     {'itemId': 'Q1289248', 'enLabel': 'scalar'},
#     {'itemId': 'Q309314', 'enLabel': 'quantity'},
#     {'itemId': 'Q122375923', 'enLabel': 'abstract class'},
#     {'itemId': 'Q4373292', 'enLabel': 'physical property'},
#     {'itemId': 'Q2204117', 'enLabel': 'symmetric tensor'},
#     {'itemId': 'Q1325769', 'enLabel': 'antisymmetric tensor'},
#     {'itemId': 'Q2091629', 'enLabel': 'magnitude'},
#     {'itemId': 'Q2912517', 'enLabel': 'value'},
#     {'itemId': 'Q38885242', 'enLabel': 'physico-chemical property'},
#     {'itemId': 'Q188524', 'enLabel': 'tensor'},
#     {'itemId': 'Q930933', 'enLabel': 'relation'},
#     {'itemId': 'Q246672', 'enLabel': 'mathematical object'},
#     {'itemId': 'Q1952404', 'enLabel': 'multilinear map'},
#     {'itemId': 'Q30060700', 'enLabel': 'scientific object'},
#     {'itemId': 'Q370502', 'enLabel': 'mapping'},
#     {'itemId': 'Q11348', 'enLabel': 'function'},
#     {'itemId': 'Q29182544', 'enLabel': 'assignment'},
#     {'itemId': 'Q130901', 'enLabel': 'binary relation'},
#     {'itemId': 'Q1756942', 'enLabel': 'partial function'},
#     {'itemId': 'Q629085', 'enLabel': 'multivalued function'},
#     {'itemId': 'Q846537', 'enLabel': 'generalized function'},
#     {'itemId': 'Q4026292', 'enLabel': 'action'},
#     {'itemId': 'Q203066', 'enLabel': 'relation'},
#     {'itemId': 'Q54940067', 'enLabel': 'serial relation'},
#     {'itemId': 'Q1190554', 'enLabel': 'occurrence'},
#     {'itemId': 'Q36161', 'enLabel': 'set'},
#     {'itemId': 'Q107223533', 'enLabel': 'relation (mathematics)'},
#     {'itemId': 'Q67518978', 'enLabel': 'occurrent'},
#     {'itemId': 'Q217594', 'enLabel': 'class'},
#     {'itemId': 'Q5469988', 'enLabel': 'formalization'},
#     {'itemId': 'Q864377', 'enLabel': 'multiset'},
#     {'itemId': 'Q748349', 'enLabel': 'mathematical structure'},
#     {'itemId': 'Q4393498', 'enLabel': 'representation'},
#     {'itemId': 'Q4833865', 'enLabel': 'abstract structure'}],
#    'dbPediaTypes': [],
#    'dbPediaIri': 'http://dbpedia.org/resource/Systems_development_life-cycle',
#    'supportLen': 1,
#    'support': [{'wFrom': 295,
#      'wTo': 295,
#      'chFrom': 1166,
#      'chTo': 1167,
#      'pMentionGivenSurface': 0.005767012687427913,
#      'pageRank': 4.116280643729791e-05,
#      'prbConfidence': 0.3637108171663799,
#      'entropy': 2.753918758180346}]},
#   {'title': '유튜브',
#    'url': 'http://ko.wikipedia.org/wiki/%ec%9c%a0%ed%8a%9c%eb%b8%8c',
#    'lang': 'ko',
#    'pageRank': 0.0107702077005964,
#    'cosine': 0.05158517979002475,
#    'secLang': 'en',
#    'secTitle': 'YouTube',
#    'secUrl': 'http://en.wikipedia.org/wiki/YouTube',
#    'wikiDataItemId': 'Q866',
#    'wikiDataClasses': [{'itemId': 'Q59152282',
#      'enLabel': 'video streaming service'},
#     {'itemId': 'Q559856', 'enLabel': 'online video platform'},
#     {'itemId': 'Q122759350', 'enLabel': 'user-generated content platform'},
#     {'itemId': 'Q6576792', 'enLabel': 'online community'},
#     {'itemId': 'Q102336293', 'enLabel': 'live streaming service'},
#     {'itemId': 'Q63241860', 'enLabel': 'streaming service'},
#     {'itemId': 'Q104632637', 'enLabel': 'video streaming'},
#     {'itemId': 'Q1668024', 'enLabel': 'service on Internet'},
#     {'itemId': 'Q56611700', 'enLabel': 'Internet industry'},
#     {'itemId': 'Q210980', 'enLabel': 'virtual community'},
#     {'itemId': 'Q35127', 'enLabel': 'website'},
#     {'itemId': 'Q19307174', 'enLabel': 'digital distribution platform'},
#     {'itemId': 'Q220499', 'enLabel': 'streaming media'},
#     {'itemId': 'Q1273271', 'enLabel': 'e-service'},
#     {'itemId': 'Q1640628', 'enLabel': 'network service'},
#     {'itemId': 'Q340169', 'enLabel': 'media'},
#     {'itemId': 'Q177634', 'enLabel': 'community'},
#     {'itemId': 'Q131164', 'enLabel': 'Web 2.0'},
#     {'itemId': 'Q1076968', 'enLabel': 'digital media'},
#     {'itemId': 'Q1714118', 'enLabel': 'online publication'},
#     {'itemId': 'Q19967801', 'enLabel': 'online service'},
#     {'itemId': 'Q107307154', 'enLabel': 'virtual place'},
#     {'itemId': 'Q108637623', 'enLabel': 'integrating resource'},
#     {'itemId': 'Q119648796', 'enLabel': 'digital-native publication'},
#     {'itemId': 'Q7397', 'enLabel': 'software'},
#     {'itemId': 'Q241317', 'enLabel': 'computing platform'},
#     {'itemId': 'Q8513', 'enLabel': 'database'},
#     {'itemId': 'Q1172540', 'enLabel': 'data stream'},
#     {'itemId': 'Q7406919', 'enLabel': 'service'},
#     {'itemId': 'Q146923', 'enLabel': 'middleware of distributed system'},
#     {'itemId': 'Q12774177', 'enLabel': 'means'},
#     {'itemId': 'Q104450446', 'enLabel': 'data carrier'},
#     {'itemId': 'Q874405', 'enLabel': 'human social group'},
#     {'itemId': 'Q16334295', 'enLabel': 'group of humans'},
#     {'itemId': 'Q21157127', 'enLabel': 'cluster'},
#     {'itemId': 'Q1209283', 'enLabel': 'electronic media'},
#     {'itemId': 'Q732577', 'enLabel': 'publication'},
#     {'itemId': 'Q11492760', 'enLabel': 'information services'},
#     {'itemId': 'Q115095765', 'enLabel': 'location'},
#     {'itemId': 'Q17537576', 'enLabel': 'creative work'},
#     {'itemId': 'Q47461344', 'enLabel': 'written work'},
#     {'itemId': 'Q2424752', 'enLabel': 'product'},
#     {'itemId': 'Q994895', 'enLabel': 'technical system'},
#     {'itemId': 'Q1172284', 'enLabel': 'data set'},
#     {'itemId': 'Q386724', 'enLabel': 'work'},
#     {'itemId': 'Q59138870', 'enLabel': 'digital object'},
#     {'itemId': 'Q494756', 'enLabel': 'data'},
#     {'itemId': 'Q20937557', 'enLabel': 'sequence'},
#     {'itemId': 'Q2897903', 'enLabel': 'goods and services'},
#     {'itemId': 'Q8187769', 'enLabel': 'economic activity'},
#     {'itemId': 'Q146768', 'enLabel': 'middleware'},
#     {'itemId': 'Q17538423', 'enLabel': 'manifestation'},
#     {'itemId': 'Q1639378', 'enLabel': 'social system'},
#     {'itemId': 'Q16334298', 'enLabel': 'group of living things'},
#     {'itemId': 'Q16887380', 'enLabel': 'group'},
#     {'itemId': 'Q115668308', 'enLabel': 'release'},
#     {'itemId': 'Q49848', 'enLabel': 'document'},
#     {'itemId': 'Q35120', 'enLabel': 'entity'},
#     {'itemId': 'Q15621286', 'enLabel': 'intellectual work'},
#     {'itemId': 'Q2143054', 'enLabel': 'material culture'},
#     {'itemId': 'Q488383', 'enLabel': 'object'},
#     {'itemId': 'Q58778', 'enLabel': 'system'},
#     {'itemId': 'Q16686448', 'enLabel': 'artificial object'},
#     {'itemId': 'Q2668072', 'enLabel': 'collection'},
#     {'itemId': 'Q286583', 'enLabel': 'manifestation'},
#     {'itemId': 'Q1791627', 'enLabel': 'cultural artifact'},
#     {'itemId': 'Q82753', 'enLabel': 'computer file'},
#     {'itemId': 'Q42848', 'enLabel': 'data'},
#     {'itemId': 'Q3523102', 'enLabel': 'source of information'},
#     {'itemId': 'Q16889133', 'enLabel': 'class'},
#     {'itemId': 'Q58415929', 'enLabel': 'spatio-temporal entity'},
#     {'itemId': 'Q451967', 'enLabel': 'intentional human activity'},
#     {'itemId': 'Q125506646', 'enLabel': 'transfer'},
#     {'itemId': 'Q676202', 'enLabel': 'system software'},
#     {'itemId': 'Q61961344', 'enLabel': 'group of physical objects'},
#     {'itemId': 'Q99527517', 'enLabel': 'collective entity'},
#     {'itemId': 'Q37866906', 'enLabel': 'information resource'},
#     {'itemId': 'Q131257', 'enLabel': 'intellectual property'},
#     {'itemId': 'Q11042', 'enLabel': 'culture'},
#     {'itemId': 'Q23498', 'enLabel': 'archaeology'},
#     {'itemId': 'Q23404', 'enLabel': 'anthropology'},
#     {'itemId': 'Q7048977', 'enLabel': 'abstract entity'},
#     {'itemId': 'Q17489659', 'enLabel': 'group of works'},
#     {'itemId': 'Q7725310', 'enLabel': 'series of creative works'},
#     {'itemId': 'Q210272', 'enLabel': 'cultural heritage'},
#     {'itemId': 'Q37787110', 'enLabel': 'file system object'},
#     {'itemId': 'Q11028', 'enLabel': 'information'},
#     {'itemId': 'Q31464082', 'enLabel': 'source'},
#     {'itemId': 'Q5127848', 'enLabel': 'class'},
#     {'itemId': 'Q61788060', 'enLabel': 'human activity'},
#     {'itemId': 'Q1150070', 'enLabel': 'change'},
#     {'itemId': 'Q52948', 'enLabel': 'interaction'},
#     {'itemId': 'Q98119401', 'enLabel': 'group or class of physical objects'},
#     {'itemId': 'Q1554231', 'enLabel': 'resource'},
#     {'itemId': 'Q1400881', 'enLabel': 'property'},
#     {'itemId': 'Q427581', 'enLabel': 'intangible asset'},
#     {'itemId': 'Q1146011', 'enLabel': 'exclusive right'},
#     {'itemId': 'Q332624', 'enLabel': 'erga omnes'},
#     {'itemId': 'Q2515887', 'enLabel': 'pattern of behavior'},
#     {'itemId': 'Q1066186', 'enLabel': 'study of history'},
#     {'itemId': 'Q34749', 'enLabel': 'social science'},
#     {'itemId': 'Q2434238', 'enLabel': 'heritage'},
#     {'itemId': 'Q30059018', 'enLabel': 'operating system component'},
#     {'itemId': 'Q216601', 'enLabel': 'object'},
#     {'itemId': 'Q9081', 'enLabel': 'knowledge'},
#     {'itemId': 'Q1914636', 'enLabel': 'activity'},
#     {'itemId': 'Q3769299', 'enLabel': 'human behavior'},
#     {'itemId': 'Q67518978', 'enLabel': 'occurrent'},
#     {'itemId': 'Q111931734', 'enLabel': 'effect'},
#     {'itemId': 'Q930933', 'enLabel': 'relation'},
#     {'itemId': 'Q53617489', 'enLabel': 'independent continuant'},
#     {'itemId': 'Q28877', 'enLabel': 'goods'},
#     {'itemId': 'Q46737', 'enLabel': 'asset'},
#     {'itemId': 'Q6042535', 'enLabel': 'intangible property'},
#     {'itemId': 'Q780687', 'enLabel': 'rights'},
#     {'itemId': 'Q2386606', 'enLabel': 'subjective right'},
#     {'itemId': 'Q2083958', 'enLabel': 'pattern'},
#     {'itemId': 'Q80083', 'enLabel': 'humanities'},
#     {'itemId': 'Q33122512', 'enLabel': 'social sciences and humanities'},
#     {'itemId': 'Q17176533', 'enLabel': 'software component'},
#     {'itemId': 'Q1196827', 'enLabel': 'value'},
#     {'itemId': 'Q2198779', 'enLabel': 'unit'},
#     {'itemId': 'Q104127086', 'enLabel': 'memory'},
#     {'itemId': 'Q3249551', 'enLabel': 'process'},
#     {'itemId': 'Q9332', 'enLabel': 'behavior'},
#     {'itemId': 'Q4026292', 'enLabel': 'action'},
#     {'itemId': 'Q937228', 'enLabel': 'property'},
#     {'itemId': 'Q103940464', 'enLabel': 'continuant'},
#     {'itemId': 'Q2135465', 'enLabel': 'legal concept'},
#     {'itemId': 'Q321839', 'enLabel': 'agreement'},
#     {'itemId': 'Q7748', 'enLabel': 'law'},
#     {'itemId': 'Q4184950', 'enLabel': 'regularity'},
#     {'itemId': 'Q11862829', 'enLabel': 'academic discipline'},
#     {'itemId': 'Q336', 'enLabel': 'science'},
#     {'itemId': 'Q66310127', 'enLabel': 'immaterial component'},
#     {'itemId': 'Q110832782', 'enLabel': 'software resource'},
#     {'itemId': 'Q778379', 'enLabel': 'expression'},
#     {'itemId': 'Q1786828', 'enLabel': 'constituent'},
#     {'itemId': 'Q47574', 'enLabel': 'unit of measurement'},
#     {'itemId': 'Q12488383', 'enLabel': 'content'},
#     {'itemId': 'Q1190554', 'enLabel': 'occurrence'},
#     {'itemId': 'Q151885', 'enLabel': 'concept'},
#     {'itemId': 'Q1969448', 'enLabel': 'term'},
#     {'itemId': 'Q2006324', 'enLabel': 'agreement'},
#     {'itemId': 'Q1151067', 'enLabel': 'rule'},
#     {'itemId': 'Q1047113', 'enLabel': 'specialty'},
#     {'itemId': 'Q105948247', 'enLabel': 'knowledge system'},
#     {'itemId': 'Q1310239', 'enLabel': 'component'},
#     {'itemId': 'Q115642239', 'enLabel': 'computer language manifestation'},
#     {'itemId': 'Q5371079', 'enLabel': 'emic unit'},
#     {'itemId': 'Q39875001', 'enLabel': 'measure'},
#     {'itemId': 'Q181175', 'enLabel': 'scalar quantity'},
#     {'itemId': 'Q71550118', 'enLabel': 'individual quantity'},
#     {'itemId': 'Q15916540', 'enLabel': 'semantic unit'},
#     {'itemId': 'Q2145290', 'enLabel': 'mental representation'},
#     {'itemId': 'Q1347367', 'enLabel': 'aptitude'},
#     {'itemId': 'Q115372263', 'enLabel': 'word or phrase'},
#     {'itemId': 'Q151411', 'enLabel': 'designation'},
#     {'itemId': 'Q202722', 'enLabel': 'consensus'},
#     {'itemId': 'Q628523', 'enLabel': 'message'},
#     {'itemId': 'Q110403031', 'enLabel': 'knowledge type'},
#     {'itemId': 'Q26256810', 'enLabel': 'matter'},
#     {'itemId': 'Q3622126', 'enLabel': 'conceptual system'},
#     {'itemId': 'Q15989253', 'enLabel': 'part'},
#     {'itemId': 'Q337060', 'enLabel': 'perceptible physical object'},
#     {'itemId': 'Q11953984', 'enLabel': 'linguistic unit'},
#     {'itemId': 'Q1207505', 'enLabel': 'quality'},
#     {'itemId': 'Q107715', 'enLabel': 'physical quantity'},
#     {'itemId': 'Q1289248', 'enLabel': 'scalar'},
#     {'itemId': 'Q309314', 'enLabel': 'quantity'},
#     {'itemId': 'Q122375923', 'enLabel': 'abstract class'},
#     {'itemId': 'Q1272626', 'enLabel': 'representation'},
#     {'itemId': 'Q115786086', 'enLabel': 'linguistic form'},
#     {'itemId': 'Q3505845', 'enLabel': 'state'},
#     {'itemId': 'Q21146257', 'enLabel': 'type'},
#     {'itemId': 'Q223557', 'enLabel': 'physical object'},
#     {'itemId': 'Q4373292', 'enLabel': 'physical property'},
#     {'itemId': 'Q2204117', 'enLabel': 'symmetric tensor'},
#     {'itemId': 'Q1325769', 'enLabel': 'antisymmetric tensor'},
#     {'itemId': 'Q2091629', 'enLabel': 'magnitude'},
#     {'itemId': 'Q2912517', 'enLabel': 'value'},
#     {'itemId': 'Q3695082', 'enLabel': 'sign'},
#     {'itemId': 'Q115820013', 'enLabel': 'unit of speech'},
#     {'itemId': 'Q483247', 'enLabel': 'phenomenon'},
#     {'itemId': 'Q53617407', 'enLabel': 'material entity'},
#     {'itemId': 'Q4406616', 'enLabel': 'concrete object'},
#     {'itemId': 'Q38885242', 'enLabel': 'physico-chemical property'},
#     {'itemId': 'Q188524', 'enLabel': 'tensor'},
#     {'itemId': 'Q246672', 'enLabel': 'mathematical object'},
#     {'itemId': 'Q30241068', 'enLabel': 'observable entity'},
#     {'itemId': 'Q1952404', 'enLabel': 'multilinear map'},
#     {'itemId': 'Q30060700', 'enLabel': 'scientific object'},
#     {'itemId': 'Q370502', 'enLabel': 'mapping'},
#     {'itemId': 'Q11348', 'enLabel': 'function'},
#     {'itemId': 'Q29182544', 'enLabel': 'assignment'},
#     {'itemId': 'Q130901', 'enLabel': 'binary relation'},
#     {'itemId': 'Q1756942', 'enLabel': 'partial function'},
#     {'itemId': 'Q629085', 'enLabel': 'multivalued function'},
#     {'itemId': 'Q846537', 'enLabel': 'generalized function'},
#     {'itemId': 'Q203066', 'enLabel': 'relation'},
#     {'itemId': 'Q54940067', 'enLabel': 'serial relation'},
#     {'itemId': 'Q36161', 'enLabel': 'set'},
#     {'itemId': 'Q107223533', 'enLabel': 'relation (mathematics)'},
#     {'itemId': 'Q217594', 'enLabel': 'class'},
#     {'itemId': 'Q5469988', 'enLabel': 'formalization'},
#     {'itemId': 'Q864377', 'enLabel': 'multiset'},
#     {'itemId': 'Q748349', 'enLabel': 'mathematical structure'},
#     {'itemId': 'Q4393498', 'enLabel': 'representation'},
#     {'itemId': 'Q4833865', 'enLabel': 'abstract structure'}],
#    'dbPediaTypes': ['Agent', 'Organisation', 'Company'],
#    'dbPediaIri': 'http://dbpedia.org/resource/YouTube',
#    'supportLen': 1,
#    'support': [{'wFrom': 308,
#      'wTo': 308,
#      'chFrom': 1215,
#      'chTo': 1217,
#      'pMentionGivenSurface': 0.4969996470172962,
#      'pageRank': 0.003547399906744885,
#      'prbConfidence': 1,
#      'entropy': 0}]},
#   {'title': 'C (프로그래밍 언어)',
#    'url': 'http://ko.wikipedia.org/wiki/C_(%ed%94%84%eb%a1%9c%ea%b7%b8%eb%9e%98%eb%b0%8d_%ec%96%b8%ec%96%b4)',
#    'lang': 'ko',
#    'pageRank': 0.01867279120363678,
#    'cosine': 0.05529288932363374,
#    'secLang': 'en',
#    'secTitle': 'C (programming language)',
#    'secUrl': 'http://en.wikipedia.org/wiki/C_(programming_language)',
#    'wikiDataItemId': 'Q15777',
#    'wikiDataClasses': [{'itemId': 'Q21562092',
#      'enLabel': 'imperative programming language'},
#     {'itemId': 'Q28922885', 'enLabel': 'procedural programming language'},
#     {'itemId': 'Q28920117', 'enLabel': 'structured programming language'},
#     {'itemId': 'Q651794', 'enLabel': 'compiled language'},
#     {'itemId': 'Q9143', 'enLabel': 'programming language'},
#     {'itemId': 'Q66747126', 'enLabel': 'computer science term'},
#     {'itemId': 'Q188267', 'enLabel': 'programming paradigm'},
#     {'itemId': 'Q629206', 'enLabel': 'computer language'},
#     {'itemId': 'Q12812139', 'enLabel': 'technical term'},
#     {'itemId': 'Q28643', 'enLabel': 'paradigm'},
#     {'itemId': 'Q962139', 'enLabel': 'programming style'},
#     {'itemId': 'Q192161', 'enLabel': 'formal language'},
#     {'itemId': 'Q15621286', 'enLabel': 'intellectual work'},
#     {'itemId': 'Q1969448', 'enLabel': 'term'},
#     {'itemId': 'Q2083958', 'enLabel': 'pattern'},
#     {'itemId': 'Q1292119', 'enLabel': 'style'},
#     {'itemId': 'Q36161', 'enLabel': 'set'},
#     {'itemId': 'Q649732', 'enLabel': 'formal system'},
#     {'itemId': 'Q386724', 'enLabel': 'work'},
#     {'itemId': 'Q131257', 'enLabel': 'intellectual property'},
#     {'itemId': 'Q115372263', 'enLabel': 'word or phrase'},
#     {'itemId': 'Q151411', 'enLabel': 'designation'},
#     {'itemId': 'Q4184950', 'enLabel': 'regularity'},
#     {'itemId': 'Q1207505', 'enLabel': 'quality'},
#     {'itemId': 'Q217594', 'enLabel': 'class'},
#     {'itemId': 'Q5469988', 'enLabel': 'formalization'},
#     {'itemId': 'Q864377', 'enLabel': 'multiset'},
#     {'itemId': 'Q3622126', 'enLabel': 'conceptual system'},
#     {'itemId': 'Q16686448', 'enLabel': 'artificial object'},
#     {'itemId': 'Q1791627', 'enLabel': 'cultural artifact'},
#     {'itemId': 'Q1400881', 'enLabel': 'property'},
#     {'itemId': 'Q427581', 'enLabel': 'intangible asset'},
#     {'itemId': 'Q1146011', 'enLabel': 'exclusive right'},
#     {'itemId': 'Q332624', 'enLabel': 'erga omnes'},
#     {'itemId': 'Q115786086', 'enLabel': 'linguistic form'},
#     {'itemId': 'Q7048977', 'enLabel': 'abstract entity'},
#     {'itemId': 'Q937228', 'enLabel': 'property'},
#     {'itemId': 'Q246672', 'enLabel': 'mathematical object'},
#     {'itemId': 'Q748349', 'enLabel': 'mathematical structure'},
#     {'itemId': 'Q4393498', 'enLabel': 'representation'},
#     {'itemId': 'Q58778', 'enLabel': 'system'},
#     {'itemId': 'Q151885', 'enLabel': 'concept'},
#     {'itemId': 'Q488383', 'enLabel': 'object'},
#     {'itemId': 'Q210272', 'enLabel': 'cultural heritage'},
#     {'itemId': 'Q28877', 'enLabel': 'goods'},
#     {'itemId': 'Q46737', 'enLabel': 'asset'},
#     {'itemId': 'Q6042535', 'enLabel': 'intangible property'},
#     {'itemId': 'Q780687', 'enLabel': 'rights'},
#     {'itemId': 'Q2386606', 'enLabel': 'subjective right'},
#     {'itemId': 'Q11953984', 'enLabel': 'linguistic unit'},
#     {'itemId': 'Q115820013', 'enLabel': 'unit of speech'},
#     {'itemId': 'Q35120', 'enLabel': 'entity'},
#     {'itemId': 'Q30060700', 'enLabel': 'scientific object'},
#     {'itemId': 'Q4833865', 'enLabel': 'abstract structure'},
#     {'itemId': 'Q930933', 'enLabel': 'relation'},
#     {'itemId': 'Q99527517', 'enLabel': 'collective entity'},
#     {'itemId': 'Q15916540', 'enLabel': 'semantic unit'},
#     {'itemId': 'Q2145290', 'enLabel': 'mental representation'},
#     {'itemId': 'Q1347367', 'enLabel': 'aptitude'},
#     {'itemId': 'Q2434238', 'enLabel': 'heritage'},
#     {'itemId': 'Q2897903', 'enLabel': 'goods and services'},
#     {'itemId': 'Q2424752', 'enLabel': 'product'},
#     {'itemId': 'Q1554231', 'enLabel': 'resource'},
#     {'itemId': 'Q2135465', 'enLabel': 'legal concept'},
#     {'itemId': 'Q321839', 'enLabel': 'agreement'},
#     {'itemId': 'Q7748', 'enLabel': 'law'},
#     {'itemId': 'Q2198779', 'enLabel': 'unit'},
#     {'itemId': 'Q1786828', 'enLabel': 'constituent'},
# ...
#      'linkCount': 1,
#      'pageRank': 0.00217206347255214,
#      'prbConfidence': 0.05553159763683176,
#      'linPr': 0.7308533916849015,
#      'linkProb': 0.001845018450184502,
#      'logLinkProb': 0.1370751936670521},
#     {'title': '근구수왕',
#      'url': 'http://ko.wikipedia.org/wiki/%ea%b7%bc%ea%b5%ac%ec%88%98%ec%99%95',
#      'cosine': 0.01837801546499965,
#      'linkCount': 1,
#      'pageRank': 0.0006466411425902274,
#      'prbConfidence': 0.01653221289318453,
#      'linPr': 0.4398249452954048,
#      'linkProb': 0.001845018450184502,
#      'logLinkProb': 0.1370751936670521},
#     {'title': '공격수',
#      'url': 'http://ko.wikipedia.org/wiki/%ea%b3%b5%ea%b2%a9%ec%88%98',
#      'cosine': -99,
#      'linkCount': 1,
#      'pageRank': -1,
#      'prbConfidence': -1,
#      'linPr': -1,
#      'linkProb': 0.001845018450184502,
#      'logLinkProb': 0.1370751936670521},
#     {'title': '숫자',
#      'url': 'http://ko.wikipedia.org/wiki/%ec%88%ab%ec%9e%90',
#      'cosine': -99,
#      'linkCount': 1,
#      'pageRank': -1,
#      'prbConfidence': -1,
#      'linPr': -1,
#      'linkProb': 0.001845018450184502,
#      'logLinkProb': 0.1370751936670521},
#     {'title': '이십팔수',
#      'url': 'http://ko.wikipedia.org/wiki/%ec%9d%b4%ec%8b%ad%ed%8c%94%ec%88%98',
#      'cosine': -99,
#      'linkCount': 1,
#      'pageRank': -1,
#      'prbConfidence': -1,
#      'linPr': -1,
#      'linkProb': 0.001845018450184502,
#      'logLinkProb': 0.1370751936670521}],
#    'nCandsIgnoredDueToLowLinkCount': 0,
#    'nCandsIgnoredDueToLowRelLinkCount': 0,
#    'nCandsIgnoredDueToWikiDataClass': 3},
#   {'wFrom': 548,
#    'wTo': 548,
#    'pageRank': 7.480870580509665e-05,
#    'prbConfidence': 0.557141540422661,
#    'pMentionGivenSurface': 0.01048088779284834,
#    'nodeId': 31044,
#    'mentionEntropy': 1.038920595031593,
#    'minDf': -1,
#    'wordsUsed': ['기초'],
#    'candidates': [{'title': '기초',
#      'url': 'http://ko.wikipedia.org/wiki/%ea%b8%b0%ec%b4%88',
#      'cosine': 0.03492687873555175,
#      'linkCount': 12,
#      'pageRank': 0.0006554738913241348,
#      'prbConfidence': 0.557141540422661,
#      'linPr': 0.4442013129102845,
#      'linkProb': 0.8,
#      'logLinkProb': 0.939821863455926,
#      'score2': 0.0006554738913241348,
#      'isBestCand': True},
#     {'title': '노히메',
#      'url': 'http://ko.wikipedia.org/wiki/%eb%85%b8%ed%9e%88%eb%a9%94',
#      'cosine': 0.0291401013552636,
#      'linkCount': 1,
#      'pageRank': 0.0002571601278596025,
#      'prbConfidence': 0.2185816882523815,
#      'linPr': 0.2319474835886214,
#      'linkProb': 0.06666666666666667,
#      'logLinkProb': 0.269683511755788},
#     {'title': '기초 의회',
#      'url': 'http://ko.wikipedia.org/wiki/%ea%b8%b0%ec%b4%88_%ec%9d%98%ed%9a%8c',
#      'cosine': 0.02109949285135629,
#      'linkCount': 1,
#      'pageRank': 0.0001172496045686045,
#      'prbConfidence': 0.09966014843297073,
#      'linPr': 0.1312910284463895,
#      'linkProb': 0.06666666666666667,
#      'logLinkProb': 0.269683511755788},
#     {'title': '황기 (식물)',
#      'url': 'http://ko.wikipedia.org/wiki/%ed%99%a9%ea%b8%b0_(%ec%8b%9d%eb%ac%bc)',
#      'cosine': 0.004598111556845438,
#      'linkCount': 1,
#      'pageRank': 0.0001466107565210739,
#      'prbConfidence': 0.1246166228919867,
#      'linPr': 0.1531728665207877,
#      'linkProb': 0.06666666666666667,
#      'logLinkProb': 0.269683511755788},
#     {'title': '초안',
#      'url': 'http://ko.wikipedia.org/wiki/%ec%b4%88%ec%95%88',
#      'cosine': -99,
#      'linkCount': 1,
#      'pageRank': -1,
#      'prbConfidence': -1,
#      'linPr': -1,
#      'ignoredDueToWikiDataClass': True,
#      'wikiDataImmediateClass': 'Q27949697',
#      'wikiDataRejectedAncestorClass': 'Q17379835',
#      'wikiDataPageItem': 'Q560361'},
#     {'title': '기초 (동음이의)',
#      'url': 'http://ko.wikipedia.org/wiki/%ea%b8%b0%ec%b4%88_(%eb%8f%99%ec%9d%8c%ec%9d%b4%ec%9d%98)',
#      'cosine': -99,
#      'linkCount': 1,
#      'pageRank': -1,
#      'prbConfidence': -1,
#      'linPr': -1,
#      'ignoredDueToWikiDataClass': True,
#      'wikiDataImmediateClass': 'Q4167410',
#      'wikiDataRejectedAncestorClass': 'Q17379835',
#      'wikiDataPageItem': 'Q42821019'}],
#    'nCandsIgnoredDueToLowLinkCount': 0,
#    'nCandsIgnoredDueToLowRelLinkCount': 0,
#    'nCandsIgnoredDueToWikiDataClass': 2},
#   {'wFrom': 551,
#    'wTo': 551,
#    'pageRank': 3.556368030008698e-06,
#    'prbConfidence': 1,
#    'pMentionGivenSurface': 0.0004982561036372695,
#    'nodeId': 3681694,
#    'mentionEntropy': 0,
#    'minDf': -1,
#    'wordsUsed': ['있습니다'],
#    'candidates': [{'title': '구글',
#      'url': 'http://ko.wikipedia.org/wiki/%ea%b5%ac%ea%b8%80',
#      'cosine': 0.04827900548829601,
#      'linkCount': 1,
#      'pageRank': 0.01254594287561885,
#      'prbConfidence': 1,
#      'linPr': 0.9934354485776805,
#      'linkProb': 1,
#      'logLinkProb': 1,
#      'score2': 0.01254594287561885,
#      'isBestCand': True}],
#    'nCandsIgnoredDueToLowLinkCount': 0,
#    'nCandsIgnoredDueToLowRelLinkCount': 0,
#    'nCandsIgnoredDueToWikiDataClass': 0},
#   {'wFrom': 552,
#    'wTo': 552,
#    'pageRank': 3.627766524130855e-05,
#    'prbConfidence': 1,
#    'pMentionGivenSurface': 0.005082592121982211,
#    'nodeId': 639688,
#    'mentionEntropy': 0,
#    'minDf': -1,
#    'wordsUsed': ['관심'],
#    'candidates': [{'title': '관심',
#      'url': 'http://ko.wikipedia.org/wiki/%ea%b4%80%ec%8b%ac',
#      'cosine': -99,
#      'linkCount': 3,
#      'pageRank': -1,
#      'prbConfidence': -1,
#      'linPr': -1,
#      'ignoredDueToWikiDataClass': True,
#      'wikiDataImmediateClass': 'Q4167410',
#      'wikiDataRejectedAncestorClass': 'Q17379835',
#      'wikiDataPageItem': 'Q65236737'},
#     {'title': '흥미',
#      'url': 'http://ko.wikipedia.org/wiki/%ed%9d%a5%eb%af%b8',
#      'cosine': 0.01294203840643354,
#      'linkCount': 2,
#      'pageRank': 0.001013088874487348,
#      'prbConfidence': 1,
#      'linPr': 0.5382932166301969,
#      'linkProb': 1,
#      'logLinkProb': 1,
#      'score2': 0.001013088874487348,
#      'isBestCand': True}],
#    'nCandsIgnoredDueToLowLinkCount': 0,
#    'nCandsIgnoredDueToLowRelLinkCount': 0,
#    'nCandsIgnoredDueToWikiDataClass': 1},
#   {'wFrom': 555,
#    'wTo': 555,
#    'pageRank': 0.0001271281526705264,
#    'prbConfidence': 0.2811780767496876,
#    'pMentionGivenSurface': 0.01781097385808676,
#    'nodeId': 6334,
#    'mentionEntropy': 1.563022039199793,
#    'minDf': -1,
#    'wordsUsed': ['영상'],
#    'candidates': [{'title': '영상',
#      'url': 'http://ko.wikipedia.org/wiki/%ec%98%81%ec%83%81',
#      'cosine': 0.03302875395134203,
#      'linkCount': 45,
#      'pageRank': 0.005671450736009782,
#      'prbConfidence': 0.2811780767496876,
#      'linPr': 0.9234135667396062,
#      'linkProb': 0.7258064516129032,
#      'logLinkProb': 0.9374949296804995,
#      'score2': 0.005671450736009782,
#      'isBestCand': True},
#     {'title': '비디오',
#      'url': 'http://ko.wikipedia.org/wiki/%eb%b9%84%eb%94%94%ec%98%a4',
#      'cosine': 0.03524424452238652,
#      'linkCount': 5,
#      'pageRank': 0.004790668254223694,
#      'prbConfidence': 0.2375108149164885,
#      'linPr': 0.8927789934354485,
#      'linkProb': 0.08064516129032258,
#      'logLinkProb': 0.508946658399544},
#     {'title': '영의정',
#      'url': 'http://ko.wikipedia.org/wiki/%ec%98%81%ec%9d%98%ec%a0%95',
#      'cosine': 0.0003293632569956547,
#      'linkCount': 3,
#      'pageRank': 0.001524906692842257,
#      'prbConfidence': 0.07560152614810137,
#      'linPr': 0.6520787746170679,
#      'linkProb': 0.04838709677419355,
#      'logLinkProb': 0.4093148591520004},
#     {'title': '영상 (전한)',
#      'url': 'http://ko.wikipedia.org/wiki/%ec%98%81%ec%83%81_(%ec%a0%84%ed%95%9c)',
#      'cosine': 0.007356748037339663,
#      'linkCount': 3,
#      'pageRank': 3.958796046353371e-05,
#      'prbConfidence': 0.001962684170895332,
#      'linPr': 0.06345733041575492,
#      'linkProb': 0.04838709677419355,
#      'logLinkProb': 0.4093148591520004},
#     {'title': '동영상',
#      'url': 'http://ko.wikipedia.org/wiki/%eb%8f%99%ec%98%81%ec%83%81',
#      'cosine': 0.04076428063222736,
#      'linkCount': 2,
#      'pageRank': 0.005035135698700417,
#      'prbConfidence': 0.2496309741253892,
#      'linPr': 0.9080962800875274,
#      'linkProb': 0.03225806451612903,
#      'logLinkProb': 0.3302326511079063},
#     {'title': '영상 (드뷔시)',
#      'url': 'http://ko.wikipedia.org/wiki/%ec%98%81%ec%83%81_(%eb%93%9c%eb%b7%94%ec%8b%9c)',
#      'cosine': 0.00347150855067409,
#      'linkCount': 2,
#      'pageRank': 5.451020471985364e-05,
#      'prbConfidence': 0.002702496281779172,
#      'linPr': 0.07221006564551423,
#      'linkProb': 0.03225806451612903,
#      'logLinkProb': 0.3302326511079063},
#     {'title': '영상의학',
#      'url': 'http://ko.wikipedia.org/wiki/%ec%98%81%ec%83%81%ec%9d%98%ed%95%99',
#      'cosine': 0,
#      'linkCount': 1,
#      'pageRank': 0.0006045676475921896,
#      'prbConfidence': 0.02997313673831787,
#      'linPr': 0.4223194748358862,
#      'linkProb': 0.01612903225806452,
#      'logLinkProb': 0.1950407235115226},
#     {'title': '디지털 영상',
#      'url': 'http://ko.wikipedia.org/wiki/%eb%94%94%ec%a7%80%ed%84%b8_%ec%98%81%ec%83%81',
#      'cosine': 0.02811253915367971,
#      'linkCount': 1,
#      'pageRank': 0.002449489074659634,
#      'prbConfidence': 0.1214402908693413,
#      'linPr': 0.7549234135667396,
#      'linkProb': 0.01612903225806452,
#      'logLinkProb': 0.1950407235115226},
#     {'title': '영상 (동음이의)',
#      'url': 'http://ko.wikipedia.org/wiki/%ec%98%81%ec%83%81_(%eb%8f%99%ec%9d%8c%ec%9d%b4%ec%9d%98)',
#      'cosine': -99,
#      'linkCount': 1,
#      'pageRank': -1,
#      'prbConfidence': -1,
#      'linPr': -1,
#      'ignoredDueToWikiDataClass': True,
#      'wikiDataImmediateClass': 'Q4167410',
#      'wikiDataRejectedAncestorClass': 'Q17379835',
#      'wikiDataPageItem': 'Q65332529'}],
#    'nCandsIgnoredDueToLowLinkCount': 0,
#    'nCandsIgnoredDueToLowRelLinkCount': 0,
#    'nCandsIgnoredDueToWikiDataClass': 1},
#   {'wFrom': 557,
#    'wTo': 557,
#    'pageRank': 0,
#    'prbConfidence': -1,
#    'pMentionGivenSurface': 0.0108695652173913,
#    'nodeId': 1111939,
#    'mentionEntropy': 0,
#    'minDf': -1,
#    'wordsUsed': ['링크를'],
#    'candidates': [{'title': '링크',
#      'url': 'http://ko.wikipedia.org/wiki/%eb%a7%81%ed%81%ac',
#      'cosine': -99,
#      'linkCount': 3,
#      'pageRank': -1,
#      'prbConfidence': -1,
#      'linPr': -1,
#      'ignoredDueToWikiDataClass': True,
#      'wikiDataImmediateClass': 'Q4167410',
#      'wikiDataRejectedAncestorClass': 'Q17379835',
#      'wikiDataPageItem': 'Q117476882'}],
#    'nCandsIgnoredDueToLowLinkCount': 0,
#    'nCandsIgnoredDueToLowRelLinkCount': 0,
#    'nCandsIgnoredDueToWikiDataClass': 1},
#   {'wFrom': 564,
#    'wTo': 564,
#    'pageRank': 0.0001271281526705264,
#    'prbConfidence': 0.2811780767496876,
#    'pMentionGivenSurface': 0.01781097385808676,
#    'nodeId': 6334,
#    'mentionEntropy': 1.563022039199793,
#    'minDf': -1,
#    'wordsUsed': ['영상'],
#    'candidates': [{'title': '영상',
#      'url': 'http://ko.wikipedia.org/wiki/%ec%98%81%ec%83%81',
#      'cosine': 0.03302875395134203,
#      'linkCount': 45,
#      'pageRank': 0.005671450736009782,
#      'prbConfidence': 0.2811780767496876,
#      'linPr': 0.9234135667396062,
#      'linkProb': 0.7258064516129032,
#      'logLinkProb': 0.9374949296804995,
#      'score2': 0.005671450736009782,
#      'isBestCand': True},
#     {'title': '비디오',
#      'url': 'http://ko.wikipedia.org/wiki/%eb%b9%84%eb%94%94%ec%98%a4',
#      'cosine': 0.03524424452238652,
#      'linkCount': 5,
#      'pageRank': 0.004790668254223694,
#      'prbConfidence': 0.2375108149164885,
#      'linPr': 0.8927789934354485,
#      'linkProb': 0.08064516129032258,
#      'logLinkProb': 0.508946658399544},
#     {'title': '영의정',
#      'url': 'http://ko.wikipedia.org/wiki/%ec%98%81%ec%9d%98%ec%a0%95',
#      'cosine': 0.0003293632569956547,
#      'linkCount': 3,
#      'pageRank': 0.001524906692842257,
#      'prbConfidence': 0.07560152614810137,
#      'linPr': 0.6520787746170679,
#      'linkProb': 0.04838709677419355,
#      'logLinkProb': 0.4093148591520004},
#     {'title': '영상 (전한)',
#      'url': 'http://ko.wikipedia.org/wiki/%ec%98%81%ec%83%81_(%ec%a0%84%ed%95%9c)',
#      'cosine': 0.007356748037339663,
#      'linkCount': 3,
#      'pageRank': 3.958796046353371e-05,
#      'prbConfidence': 0.001962684170895332,
#      'linPr': 0.06345733041575492,
#      'linkProb': 0.04838709677419355,
#      'logLinkProb': 0.4093148591520004},
#     {'title': '동영상',
#      'url': 'http://ko.wikipedia.org/wiki/%eb%8f%99%ec%98%81%ec%83%81',
#      'cosine': 0.04076428063222736,
#      'linkCount': 2,
#      'pageRank': 0.005035135698700417,
#      'prbConfidence': 0.2496309741253892,
#      'linPr': 0.9080962800875274,
#      'linkProb': 0.03225806451612903,
#      'logLinkProb': 0.3302326511079063},
#     {'title': '영상 (드뷔시)',
#      'url': 'http://ko.wikipedia.org/wiki/%ec%98%81%ec%83%81_(%eb%93%9c%eb%b7%94%ec%8b%9c)',
#      'cosine': 0.00347150855067409,
#      'linkCount': 2,
#      'pageRank': 5.451020471985364e-05,
#      'prbConfidence': 0.002702496281779172,
#      'linPr': 0.07221006564551423,
#      'linkProb': 0.03225806451612903,
#      'logLinkProb': 0.3302326511079063},
#     {'title': '영상의학',
#      'url': 'http://ko.wikipedia.org/wiki/%ec%98%81%ec%83%81%ec%9d%98%ed%95%99',
#      'cosine': 0,
#      'linkCount': 1,
#      'pageRank': 0.0006045676475921896,
#      'prbConfidence': 0.02997313673831787,
#      'linPr': 0.4223194748358862,
#      'linkProb': 0.01612903225806452,
#      'logLinkProb': 0.1950407235115226},
#     {'title': '디지털 영상',
#      'url': 'http://ko.wikipedia.org/wiki/%eb%94%94%ec%a7%80%ed%84%b8_%ec%98%81%ec%83%81',
#      'cosine': 0.02811253915367971,
#      'linkCount': 1,
#      'pageRank': 0.002449489074659634,
#      'prbConfidence': 0.1214402908693413,
#      'linPr': 0.7549234135667396,
#      'linkProb': 0.01612903225806452,
#      'logLinkProb': 0.1950407235115226},
#     {'title': '영상 (동음이의)',
#      'url': 'http://ko.wikipedia.org/wiki/%ec%98%81%ec%83%81_(%eb%8f%99%ec%9d%8c%ec%9d%b4%ec%9d%98)',
#      'cosine': -99,
#      'linkCount': 1,
#      'pageRank': -1,
#      'prbConfidence': -1,
#      'linPr': -1,
#      'ignoredDueToWikiDataClass': True,
#      'wikiDataImmediateClass': 'Q4167410',
#      'wikiDataRejectedAncestorClass': 'Q17379835',
#      'wikiDataPageItem': 'Q65332529'}],
#    'nCandsIgnoredDueToLowLinkCount': 0,
#    'nCandsIgnoredDueToLowRelLinkCount': 0,
#    'nCandsIgnoredDueToWikiDataClass': 1},
#   {'wFrom': 567,
#    'wTo': 567,
#    'pageRank': 0.0001138983612163956,
#    'prbConfidence': 1,
#    'pMentionGivenSurface': 0.01595744680851064,
#    'nodeId': 1309811,
#    'mentionEntropy': 0,
#    'minDf': -1,
#    'wordsUsed': ['감사합니다'],
#    'candidates': [{'title': '고맙습니다',
#      'url': 'http://ko.wikipedia.org/wiki/%ea%b3%a0%eb%a7%99%ec%8a%b5%eb%8b%88%eb%8b%a4',
#      'cosine': -99,
#      'linkCount': 2,
#      'pageRank': -1,
#      'prbConfidence': -1,
#      'linPr': -1,
#      'ignoredDueToWikiDataClass': True,
#      'wikiDataImmediateClass': 'Q4167410',
#      'wikiDataRejectedAncestorClass': 'Q17379835',
#      'wikiDataPageItem': 'Q16072569'},
#     {'title': '개그콘서트',
#      'url': 'http://ko.wikipedia.org/wiki/%ea%b0%9c%ea%b7%b8%ec%bd%98%ec%84%9c%ed%8a%b8',
#      'cosine': 0.001880357909201272,
#      'linkCount': 1,
#      'pageRank': 0.003486839269722707,
#      'prbConfidence': 1,
#      'linPr': 0.838074398249453,
#      'linkProb': 1,
#      'logLinkProb': 1,
#      'score2': 0.003486839269722707,
#      'isBestCand': True}],
#    'nCandsIgnoredDueToLowLinkCount': 0,
#    'nCandsIgnoredDueToLowRelLinkCount': 0,
#    'nCandsIgnoredDueToWikiDataClass': 1}],
#  'timeTotalMs': 147.576,
#  'timeAnnotationMs': 101.819,
#  'timeBuildJsonMs': 43.093,
#  'incIdxTimestampUtc': '',
#  'fnRegIdx': 'kowiki-20200301-pages-articles-index3.bin',
#  'fnWikiData': 'wikidata-20241111-all.bin',
#  'settings': {'pageRankSqThreshold': 0.8,
#   'applyPageRankSqThreshold': True,
#   'minPMentionGivenPhrase': 0,
#   'maxMentionEntropy': -1,
#   'maxTargetsPerMention': 20,
#   'useLogLinkCounts': False,
#   'candSelectionUseLinearizedPageRank': False,
#   'candSelectionPageRankThreshold': 2,
#   'candSelectionCosineWeight': 0,
#   'candSelectionLinkCtxCosineWeight': 0,
#   'candSelectionUseLinkProb': 'no',
#   'semanticSimilarity': 'in',
#   'secondaryAnnotLanguage': 'en',
#   'minLinkFrequency': 1,
#   'minLinkRelFrequency': 0,
#   'nTopDfWordsToIgnore': 0,
#   'nWordsToIgnoreFromList': 100,
#   'extraVocabsToInclude': [],
#   'altLabelSetsToUse': []},
#  'language': 'ko'}

# %%
keywords = set()
for d in wikis['ranges']:
  for candidate in d['candidates']:
    if candidate['cosine'] > 0.05:
      keywords.add(candidate['title'])
keywords
# Out:
# {'C (프로그래밍 언어)',
#  '네이버',
#  '디지털 텔레비전',
#  '병렬 컴퓨팅',
#  '블로그',
#  '생각',
#  '수 (수학)',
#  '시간',
#  '시간 복잡도',
#  '오토파일럿',
#  '유튜브',
#  '자동화',
#  '자료형',
#  '종 (생물학)',
#  '큰 수',
#  '파이썬',
#  '파일 공유'}

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# 1. 한글 폰트 설치 (나눔고딕)
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import matplotlib
import networkx as nx
from itertools import combinations

# 2. Colab 런타임에 폰트 적용
plt.rc('font', family='NanumBarunGothic')
plt.rcParams['axes.unicode_minus'] = False

# 3. 영상별 키워드 예시
# 추출한 것으로 수정 필요!
video_keywords = {
    "영상 A": {"프로그래밍 언어", "네이버", "병렬컴퓨팅"},
    "영상 B": {"파이썬", "플라스크", "웹"},
    "영상 C": {"AI", "딥러닝", "뉴럴네트워크"},
    "영상 D": {"파이썬", "AI", "넘파이"},
    "영상 E": {"웹", "HTML", "CSS"}
}

# 4. NetworkX 그래프 생성
G = nx.Graph()
G.add_nodes_from(video_keywords.keys())

for vid1, vid2 in combinations(video_keywords.keys(), 2):
    shared = video_keywords[vid1] & video_keywords[vid2]
    if shared:
        G.add_edge(vid1, vid2, weight=len(shared), label=", ".join(shared))

# 5. 시각화
pos = nx.spring_layout(G, seed=42)

plt.figure(figsize=(10, 6))
nx.draw_networkx_nodes(G, pos, node_size=1000, node_color="lightyellow")
nx.draw_networkx_labels(G, pos, font_size=12, font_family='NanumBarunGothic')
nx.draw_networkx_edges(G, pos, width=2)

# edge label 표시
edge_labels = nx.get_edge_attributes(G, "label")
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_size=10, font_family='NanumBarunGothic')

plt.title("유튜브 영상 간 공통 키워드 네트워크 ", fontsize=14)
plt.axis("off")
plt.show()
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 30 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 1s (9,646 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 126213 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20200506-1_all.deb ...
# Unpacking fonts-nanum (20200506-1) ...
# Setting up fonts-nanum (20200506-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50976 (\N{HANGUL SYLLABLE YU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 53916 (\N{HANGUL SYLLABLE TYU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48652 (\N{HANGUL SYLLABLE BEU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50689 (\N{HANGUL SYLLABLE YEONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44036 (\N{HANGUL SYLLABLE GAN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44277 (\N{HANGUL SYLLABLE GONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 53685 (\N{HANGUL SYLLABLE TONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 53412 (\N{HANGUL SYLLABLE KI}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50892 (\N{HANGUL SYLLABLE WEO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46300 (\N{HANGUL SYLLABLE DEU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 45348 (\N{HANGUL SYLLABLE NE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 53944 (\N{HANGUL SYLLABLE TEU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 53356 (\N{HANGUL SYLLABLE KEU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# /usr/local/lib/python3.11/dist-packages/networkx/drawing/nx_pylab.py:1439: UserWarning: Glyph 54028 (\N{HANGUL SYLLABLE PA}) missing from font(s) DejaVu Sans.
#   super().draw(renderer)
# /usr/local/lib/python3.11/dist-packages/networkx/drawing/nx_pylab.py:1439: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from font(s) DejaVu Sans.
#   super().draw(renderer)
# /usr/local/lib/python3.11/dist-packages/networkx/drawing/nx_pylab.py:1439: UserWarning: Glyph 50028 (\N{HANGUL SYLLABLE SSEON}) missing from font(s) DejaVu Sans.
#   super().draw(renderer)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# /usr/local/lib/python3.11/dist-packages/networkx/drawing/nx_pylab.py:1439: UserWarning: Glyph 50937 (\N{HANGUL SYLLABLE WEB}) missing from font(s) DejaVu Sans.
#   super().draw(renderer)
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumBarunGothic' not found.
